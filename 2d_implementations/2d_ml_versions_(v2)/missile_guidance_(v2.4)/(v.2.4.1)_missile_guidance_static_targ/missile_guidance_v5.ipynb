# %%
import gymnasium as gym 
from gymnasium import Env
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import tensorflow as tf
import datetime
import gymnasium as gym
import numpy as np
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
import tensorflow as tf

# # Set seed for reproducibility
# seed = 42
# random.seed(seed)
# np.random.seed(seed)

class missile_interception(Env):
    def __init__(self):
        self.action_space = gym.spaces.discrete.Discrete(3)
        low = np.array([-1, -1, -1, -1, -1, -1, -1, -1, -2, -2, -0.04, -2.828, -70.71, 0, -44.8, 0, -np.inf, -np.inf], dtype=np.float32)
        high = np.array([1, 1, 1, 1, 1, 1, 1, 1, 2, 2, 2.828, 2.828, 70.71, 149, 0, math.pi, np.inf, np.inf], dtype=np.float32)
        self.observation_space = gym.spaces.Box(low=low, high=high, dtype=np.float32)
        self.radius = 0.02

        self.episode_count = 0
        self.distance_t_minus_one = 0
        self.distance_change = 0

        self.out_of_bounds = 0
        self.interceptions = 0
        self.reached_max_steps = 0

        self.defense_positions = []
        self.attack_positions = []

        self.max_steps_per_episode = 150

    def reset(self, seed=None):
        self.defense_positions = []
        self.attack_positions = []
        self.reward = 0
        self.current_step = 0
        self.done = False
        self.create_defense()
        self.create_attack(self.defense)
        self.calc_angle(self.defense, self.attack)
        self.initial_missile_angle()
        self.missile_distance_to_attack()
        # self.graph(self.defense, self.attack)
        self.get_state()

        return self.state, {}

    def create_defense(self):
        x = random.uniform(-0.45, 0.45)
        y = random.uniform(-0.45, 0.45)
        self.defense = np.array([x, y])

    def create_attack(self, defense):
        x_side_left = random.uniform(-0.95, (defense[0] - 0.02) - 0.1)
        x_side_right = random.uniform((defense[0] + 0.02) + 0.1, 0.95)
        y_below = random.uniform((defense[1] - 0.02) - 0.1, -0.95)
        y_above = random.uniform((defense[1] + 0.02) + 0.1, 0.95)
        x_inclusive = random.uniform(-0.95, 0.95)
        y_inclusive = random.uniform(-0.95, 0.95)
        y_below_x_inclusive = np.array([x_inclusive, y_below])
        y_above_x_inclusive = np.array([x_inclusive, y_above])
        x_left_y_inclusive = np.array([x_side_left, y_inclusive])
        x_right_y_inclusive = np.array([x_side_right, y_inclusive])

        self.attack = random.choice([y_below_x_inclusive, y_above_x_inclusive, x_left_y_inclusive, x_right_y_inclusive])

    def calc_angle(self, defense, attack):

        # create an adjacent point of the form (attack_x, defense_y)
        adjacent_point = np.array([attack[0], defense[1]])

        # calculate the distance between the adjacent point and the defense, attack points
        adj_point_defense_len = abs(defense[0] - adjacent_point[0]) 
        adj_point_attack_len = abs(attack[1] - adjacent_point[1])

        # calculate the angle, using soh cah toa, where adj_point_defense_len is the adjacent side and adj_point_attack_len is the opposite side
        self.theta = np.arctan(adj_point_attack_len / adj_point_defense_len)
        
        if attack[0] > defense[0]:
            if attack[1] > defense[1]:
                self.theta = self.theta # 1st quadrant
            else: 
                self.theta = (2*math.pi) - self.theta # 360 - theta
        else:
            if attack[1] > defense[1]:
                self.theta = math.pi - self.theta # 180 - theta
            else:
                self.theta = math.pi + self.theta # 180 + theta
            
        return self.theta
    
    def initial_missile_angle(self):
        self.missile_angle = np.random.uniform(0, 2*math.pi)
        # if self.theta < math.pi:
        #     self.missile_angle = np.random.uniform(0, math.pi)
        # else:
        #     self.missile_angle = np.random.uniform(math.pi, 2*math.pi)

    def calculate_distance(self, point1, point2):
        return math.hypot(point1[0] - point2[0], point1[1] - point2[1])
    
    def missile_distance_to_attack(self):
        self.distance = (self.calculate_distance(self.defense, self.attack) - (2 * self.radius))

    def missile_nav_angle(self, action):
        if action == 0:
            self.missile_angle = self.missile_angle 
        elif action == 1:
            self.missile_angle += 0.174532925
        elif action == 2:
            self.missile_angle -= 0.174532925

    def missle_coord_calc(self):
        self.defense[0] += (0.02 * math.cos(self.missile_angle)) # gotta test this
        self.defense[1] += (0.02 * math.sin(self.missile_angle))

        self.defense_positions.append(self.defense.copy())
        self.attack_positions.append(self.attack.copy())

    def calculate_reward(self):
        self.missile_distance_to_attack()

        if self.distance < 0:
            print("HIT!")
            self.reward = 10000
            self.done = True
            self.interceptions += 1
        else:
            self.distance_change = ((self.distance - self.distance_t_minus_one) / 0.02) 
            if self.distance_change < 0:
                self.reward = -2 * (self.distance_change * (0.03 + 1/self.distance))
            else:
                self.reward = -10 * (self.distance_change * 1 + 1 * (self.distance**2))

            # angle penalty
            self.angle_diff = abs(self.theta - self.missile_angle)
            self.angle_diff = min(self.angle_diff, 2*math.pi - self.angle_diff)
            if self.angle_diff < 0.05:
                try:
                    if 1/self.angle_diff < 100:
                        self.reward += 1/self.angle_diff
                    else:
                        self.reward += 100
                except ZeroDivisionError:
                    self.reward += 100
            else:
                self.reward -= (2 * self.angle_diff)
            
            # time penalty
            self.reward -= 0.05 * self.current_step
                
        if self.defense[0] < -1 or self.defense[0] > 1 or self.defense[1] < -1 or self.defense[1] > 1:
            print("OUT OF BOUNDS")
            self.reward = -1000
            self.done = True
            self.out_of_bounds += 1

    def angle_conversion(self):
        self.sin_theta, self.sin_missile_angle = np.sin(self.theta), np.sin(self.missile_angle)
        self.cos_theta, self.cos_missile_angle = np.cos(self.theta), np.cos(self.missile_angle)

        self.delta_sin = self.sin_theta - self.sin_missile_angle
        self.delta_cos = self.cos_theta - self.cos_missile_angle

    def get_state(self):
        self.angle_conversion()
        reward_component_pos = (self.distance - self.distance_t_minus_one) / 0.02 * (0.03 + 1/self.distance) if ((self.distance - self.distance_t_minus_one) / 0.02) < 0 else 0
        reward_component_neg = (self.distance - self.distance_t_minus_one) / 0.02 * (1 + 1 * (self.distance**2)) if ((self.distance - self.distance_t_minus_one) / 0.02) >= 0 else 0

        self.state = np.array([
            self.attack[0], self.attack[1], self.defense[0], self.defense[1],
            self.sin_theta, self.cos_theta, self.sin_missile_angle, self.cos_missile_angle,
            self.delta_sin, self.delta_cos, self.distance,
            (self.distance - self.distance_t_minus_one),
            ((self.distance - self.distance_t_minus_one) / 0.02),
            self.current_step,
            (-0.05 * self.current_step),
            min(abs(self.theta - self.missile_angle), 2*math.pi - abs(self.theta - self.missile_angle)),
            reward_component_pos,
            reward_component_neg
        ])

    def get_state_dict(self):
        return {"reward": self.reward, "attack_x": self.attack[0], "attack_y": self.attack[1], "defense_x": self.defense[0], "defense_y": self.defense[1], "theta": self.theta, "missile_angle": self.missile_angle, "self.sin_theta": self.sin_theta, "self.cos_theta": self.cos_theta, "self.sin_missile_angle": self.sin_missile_angle, "self.cos_missile_angle": self.cos_missile_angle, "delta_sin": self.delta_sin, "delta_cos": self.delta_cos, "distance": self.distance, "current_step": self.current_step}
                 
    def step(self, action):
        self.distance_t_minus_one = self.distance
        self.missile_nav_angle(action)
        self.missle_coord_calc()
        self.calculate_reward()
        self.current_step += 1

        if self.current_step >= self.max_steps_per_episode:
            print("MAX STEPS REACHED")
            self.done = True
            self.reward = -1000
            self.reached_max_steps += 1

        self.get_state()

        # self.graph(self.defense, self.attack)

        return self.state, self.reward, self.done, False, {}

    def graph(self, defense, attack):
        fig, ax = plt.subplots()
        plt.xlim(-1, 1)
        plt.ylim(-1, 1)

        plt.axhline(0, color='black', linewidth=0.5)
        plt.axvline(0, color='black', linewidth=0.5)
        plt.grid(True)

        # Plot trails
        if self.defense_positions:
            defense_xs, defense_ys = zip(*self.defense_positions)
            ax.plot(defense_xs, defense_ys, 'b-')  # Blue line for defense

        if self.attack_positions:
            attack_xs, attack_ys = zip(*self.attack_positions)
            ax.plot(attack_xs, attack_ys, 'r-')  # Red line for attack

        # Plot current positions
        plt.scatter(defense[0], defense[1], color='black')
        plt.scatter(attack[0], attack[1], color='red')

        ax.set_aspect('equal')
        plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from IPython.display import HTML, display


def animate_episode(episode_data, save_name):
    episode_past_defense_positions = episode_data["past_defense_positions"]
    past_defense_x, past_defense_y = zip(*episode_past_defense_positions)
    episode_attack_positions = episode_data["attack_positions"]
    attack_x, attack_y = zip(*episode_attack_positions)
    episode_defense_positions = episode_data["defense_positions"]
    defense_x, defense_y = zip(*episode_defense_positions)

    # Create figure and axis
    fig, ax = plt.subplots()
    plt.xlim(-1, 1)
    plt.ylim(-1, 1)
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(True)

    trail, = ax.plot([], [], 'b-', label='Defense Trail')  
    scatter1, = ax.plot([], [], 'ro')  # 'ro' means red circles
    scatter2, = ax.plot([], [], 'bo')  # 'ro' means red circles

    # Update function for animation
    def update(frame):
        trail.set_data(past_defense_x[:frame+1], past_defense_y[:frame+1])
        scatter1.set_data(attack_x[frame], attack_y[frame])
        scatter2.set_data(defense_x[frame], defense_y[frame])
        return trail, scatter1, scatter2

    # Create animation
    ani = animation.FuncAnimation(fig, update, frames=len(past_defense_x), interval=200, blit=True)

    # Option 1: Save animation
    ani.save(save_name, writer='pillow')
    print(f"Animation saved as {save_name}")

    # # Option 2: Display using HTML
    # plt.close(fig)
    # video = ani.to_html5_video()
    # html = display(HTML(video))

    plt.show()

# %%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# .........................................................................................................................................................
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# COPY OF THE CODE ABOVE: THIS VERSION IS FOR TESTING THE ANIMATION FUNCTION 

from copy import deepcopy

log_number = 1

def run_episode(env, model):
    # If you have only one environment wrapped, you can directly access it
    single_env = env.envs[0]
    obs = env.reset()
    done = False
    animate = False
    total_reward = 0
    step = 0
    episode_data = None
    global log_number

    print("EPISODE NUMBER:", log_number)

    episode_data = {
    'past_defense_positions': [], # In upgraded code, we'd only need defense_positions, this is slop, let it work for now
    'attack_positions': [],
    'defense_positions': [], # because you're basically storing the same data in two different places
    }

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        episode_data['past_defense_positions'].append(deepcopy(np.array([obs[0][2], obs[0][3]])))
        obs, reward, done, info = env.step(action)
        episode_data['attack_positions'].append(deepcopy(np.array([obs[0][2], obs[0][3]])))
        episode_data['defense_positions'].append(deepcopy(np.array([obs[0][0], obs[0][1]])))
        total_reward += reward
        step += 1

    log_number += 1
    
    if episode_data is not None:
        episode_file_name = f'episode_{log_number}_v6_dqn_local.gif'
        animate_episode(episode_data, episode_file_name)

    # Now access the specific attributes from the single_env which is your actual missile_interception instance
    return step, total_reward, single_env.out_of_bounds, single_env.interceptions, single_env.reached_max_steps

# Create the environment
env = make_vec_env(lambda: missile_interception(), n_envs=1)

# Create the model
model = DQN("MlpPolicy", env, verbose=1, tensorboard_log="./dqn_missile_guidance_local_v6")

# Create a summary writer
summary_writer = tf.summary.create_file_writer('./dqn_missile_guidance_local_v6/custom_metrics')

# Training loop
total_timesteps = 2000000
eval_interval = 100000  # Evaluate and log every 10000 steps

for step in range(0, total_timesteps, eval_interval):
    # Train for a number of timesteps
    model.learn(total_timesteps=eval_interval, reset_num_timesteps=False)
    
    # Run an evaluation episode
    episode_length, episode_reward, out_of_bounds, interceptions, reached_max_steps = run_episode(env, model)
    
    # Log the results
    with summary_writer.as_default():
        tf.summary.scalar('Evaluation/Episode Length', episode_length, step=step)
        # Ensure episode_reward and other metrics are scalars by using .item() if they are numpy arrays or tensors
        tf.summary.scalar('Evaluation/Episode Reward', episode_reward.item() if isinstance(episode_reward, np.ndarray) else episode_reward, step=step)
        tf.summary.scalar('Evaluation/Out of Bounds Count', out_of_bounds.item() if isinstance(out_of_bounds, np.ndarray) else out_of_bounds, step=step)
        tf.summary.scalar('Evaluation/Interceptions Count', interceptions.item() if isinstance(interceptions, np.ndarray) else interceptions, step=step)
        tf.summary.scalar('Evaluation/Reached Max Steps Count', reached_max_steps.item() if isinstance(reached_max_steps, np.ndarray) else reached_max_steps, step=step)
        summary_writer.flush()


# Save the final model
model.save("dqn_missile_guidance_v6_local")
# Out:
# Using cpu device
# Logging to ./dqn_missile_guidance_local_v6\DQN_0
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.8     |
# |    ep_rew_mean      | -2.3e+03 |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1808     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 227      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 51.7     |
# |    n_updates        | 31       |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 63.8      |
# |    ep_rew_mean      | -2.56e+03 |
# |    exploration_rate | 0.952     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 1766      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 510       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 20.5      |
# |    n_updates        | 102       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 58.2      |
# |    ep_rew_mean      | -2.26e+03 |
# |    exploration_rate | 0.934     |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 1751      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 699       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 17.6      |
# |    n_updates        | 149       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 58.4      |
# |    ep_rew_mean      | -2.37e+03 |
# |    exploration_rate | 0.911     |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 1650      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 934       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 17        |
# |    n_updates        | 208       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 57.5      |
# |    ep_rew_mean      | -2.22e+03 |
# |    exploration_rate | 0.891     |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 1617      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1149      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 46.1      |
# |    n_updates        | 262       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 57        |
# |    ep_rew_mean      | -2.17e+03 |
# |    exploration_rate | 0.87      |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 1598      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1369      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 43.2      |
# |    n_updates        | 317       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 57.7      |
# |    ep_rew_mean      | -2.18e+03 |
# |    exploration_rate | 0.846     |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 1584      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 1616      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 12.1      |
# |    n_updates        | 378       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 58.2      |
# |    ep_rew_mean      | -2.17e+03 |
# |    exploration_rate | 0.823     |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 1562      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 1861      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 11.5      |
# |    n_updates        | 440       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 59.4      |
# |    ep_rew_mean      | -2.25e+03 |
# |    exploration_rate | 0.797     |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 1568      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2140      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 12.3      |
# |    n_updates        | 509       |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 65.5      |
# |    ep_rew_mean      | -2.33e+03 |
# |    exploration_rate | 0.751     |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 1558      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2618      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 8.21      |
# |    n_updates        | 629       |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 69.9      |
# |    ep_rew_mean      | -2.37e+03 |
# |    exploration_rate | 0.708     |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 1562      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 3075      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 70.8      |
# |    n_updates        | 743       |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 72.3      |
# |    ep_rew_mean      | -2.38e+03 |
# |    exploration_rate | 0.67      |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 1581      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 3472      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 12.4      |
# |    n_updates        | 842       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 74.5      |
# |    ep_rew_mean      | -2.46e+03 |
# |    exploration_rate | 0.632     |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 1603      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 3876      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 40.6      |
# |    n_updates        | 943       |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 79.9      |
# |    ep_rew_mean      | -2.46e+03 |
# |    exploration_rate | 0.575     |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 1595      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 4476      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 11.2      |
# |    n_updates        | 1093      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 83.2      |
# |    ep_rew_mean      | -2.47e+03 |
# |    exploration_rate | 0.526     |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 1606      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 4992      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 72        |
# |    n_updates        | 1222      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 87.4      |
# |    ep_rew_mean      | -2.49e+03 |
# |    exploration_rate | 0.469     |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 1614      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 5592      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 11.2      |
# |    n_updates        | 1372      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 91.1      |
# |    ep_rew_mean      | -2.49e+03 |
# |    exploration_rate | 0.412     |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 1620      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 6192      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.14      |
# |    n_updates        | 1522      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 94.3      |
# |    ep_rew_mean      | -2.55e+03 |
# |    exploration_rate | 0.355     |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 1618      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 6792      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.11      |
# |    n_updates        | 1672      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.3     |
# |    ep_rew_mean      | -2.6e+03 |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1613     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7392     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.92     |
# |    n_updates        | 1822     |
# ----------------------------------
# HIT!
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 98.1      |
# |    ep_rew_mean      | -2.53e+03 |
# |    exploration_rate | 0.254     |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 1609      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 7848      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36.6      |
# |    n_updates        | 1936      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 99.4      |
# |    ep_rew_mean      | -2.52e+03 |
# |    exploration_rate | 0.207     |
# | time/               |           |
# |    episodes         | 84        |
# |    fps              | 1604      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 8349      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 37.6      |
# |    n_updates        | 2062      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 101       |
# |    ep_rew_mean      | -2.54e+03 |
# |    exploration_rate | 0.153     |
# | time/               |           |
# |    episodes         | 88        |
# |    fps              | 1604      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 8916      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 34.8      |
# |    n_updates        | 2203      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 102       |
# |    ep_rew_mean      | -2.56e+03 |
# |    exploration_rate | 0.105     |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 1598      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 9421      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 8.69      |
# |    n_updates        | 2330      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 104       |
# |    ep_rew_mean      | -2.55e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 96        |
# |    fps              | 1592      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 10021     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 17.5      |
# |    n_updates        | 2480      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 103       |
# |    ep_rew_mean      | -2.52e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 100       |
# |    fps              | 1588      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 10298     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.35      |
# |    n_updates        | 2549      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 103       |
# |    ep_rew_mean      | -2.53e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 104       |
# |    fps              | 1587      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 10541     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 40        |
# |    n_updates        | 2610      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 105       |
# |    ep_rew_mean      | -2.56e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 108       |
# |    fps              | 1571      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 11036     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36.4      |
# |    n_updates        | 2733      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 107       |
# |    ep_rew_mean      | -2.59e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 112       |
# |    fps              | 1570      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 11366     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.24      |
# |    n_updates        | 2816      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# HIT!
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 108       |
# |    ep_rew_mean      | -2.51e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 116       |
# |    fps              | 1565      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 11743     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.83      |
# |    n_updates        | 2910      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 111       |
# |    ep_rew_mean      | -2.55e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 120       |
# |    fps              | 1562      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 12214     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.17      |
# |    n_updates        | 3028      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 114       |
# |    ep_rew_mean      | -2.54e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 124       |
# |    fps              | 1558      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 12732     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 97.4      |
# |    n_updates        | 3157      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# HIT!
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 115       |
# |    ep_rew_mean      | -2.49e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 128       |
# |    fps              | 1554      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 13121     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.69      |
# |    n_updates        | 3255      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -2.5e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1550     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 13583    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.2     |
# |    n_updates        | 3370     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -2.5e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1542     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13908    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.85     |
# |    n_updates        | 3451     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 116       |
# |    ep_rew_mean      | -2.49e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 140       |
# |    fps              | 1538      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 14183     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 125       |
# |    n_updates        | 3520      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 114       |
# |    ep_rew_mean      | -2.43e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 144       |
# |    fps              | 1534      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 14460     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 13.6      |
# |    n_updates        | 3589      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# HIT!
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 112       |
# |    ep_rew_mean      | -2.34e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 148       |
# |    fps              | 1530      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 14642     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.28      |
# |    n_updates        | 3635      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 111       |
# |    ep_rew_mean      | -2.27e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 152       |
# |    fps              | 1529      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 14964     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 33.9      |
# |    n_updates        | 3715      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 108       |
# |    ep_rew_mean      | -2.25e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 156       |
# |    fps              | 1525      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 15254     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 30.9      |
# |    n_updates        | 3788      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 107       |
# |    ep_rew_mean      | -2.23e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 160       |
# |    fps              | 1524      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 15687     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.39      |
# |    n_updates        | 3896      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 104       |
# |    ep_rew_mean      | -2.19e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 164       |
# |    fps              | 1522      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 16005     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.47      |
# |    n_updates        | 3976      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 101       |
# |    ep_rew_mean      | -2.15e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 168       |
# |    fps              | 1523      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 16329     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.3       |
# |    n_updates        | 4057      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 101       |
# |    ep_rew_mean      | -2.09e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 172       |
# |    fps              | 1522      |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 16849     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.44      |
# |    n_updates        | 4187      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 99.7      |
# |    ep_rew_mean      | -2.02e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 176       |
# |    fps              | 1520      |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 17357     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36.9      |
# |    n_updates        | 4314      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 98.4      |
# |    ep_rew_mean      | -2.03e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 180       |
# |    fps              | 1511      |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 17690     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.63      |
# |    n_updates        | 4397      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 98.9      |
# |    ep_rew_mean      | -2.01e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 184       |
# |    fps              | 1509      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 18237     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.27      |
# |    n_updates        | 4534      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 97.2      |
# |    ep_rew_mean      | -1.94e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 188       |
# |    fps              | 1508      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 18640     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 17.6      |
# |    n_updates        | 4634      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# HIT!
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 96.9      |
# |    ep_rew_mean      | -1.82e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 192       |
# |    fps              | 1504      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 19114     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 25.4      |
# |    n_updates        | 4753      |
# -----------------------------------
# OUT OF BOUNDS
# HIT!
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 94.8      |
# |    ep_rew_mean      | -1.76e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 196       |
# |    fps              | 1501      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 19505     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.06      |
# |    n_updates        | 4851      |
# -----------------------------------
# HIT!
# HIT!
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 96        |
# |    ep_rew_mean      | -1.66e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 200       |
# |    fps              | 1498      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 19895     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36.6      |
# |    n_updates        | 4948      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 98.6      |
# |    ep_rew_mean      | -1.64e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 204       |
# |    fps              | 1496      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 20397     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.96      |
# |    n_updates        | 5074      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -1.6e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1492     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 20997    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.1     |
# |    n_updates        | 5224     |
# ----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -1.6e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1492     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 21597    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.19     |
# |    n_updates        | 5374     |
# ----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 105       |
# |    ep_rew_mean      | -1.64e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 216       |
# |    fps              | 1489      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 22197     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.34      |
# |    n_updates        | 5524      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 105       |
# |    ep_rew_mean      | -1.61e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 220       |
# |    fps              | 1487      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 22741     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.65      |
# |    n_updates        | 5660      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 106       |
# |    ep_rew_mean      | -1.63e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 224       |
# |    fps              | 1489      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 23341     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 33.3      |
# |    n_updates        | 5810      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 108       |
# |    ep_rew_mean      | -1.74e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 228       |
# |    fps              | 1489      |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 23941     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.49      |
# |    n_updates        | 5960      |
# -----------------------------------
# MAX STEPS REACHED
# HIT!
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 108       |
# |    ep_rew_mean      | -1.65e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 232       |
# |    fps              | 1487      |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 24411     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 57.4      |
# |    n_updates        | 6077      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 111       |
# |    ep_rew_mean      | -1.67e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 236       |
# |    fps              | 1487      |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 25011     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 25.5      |
# |    n_updates        | 6227      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 114       |
# |    ep_rew_mean      | -1.68e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 240       |
# |    fps              | 1484      |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 25611     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 34.9      |
# |    n_updates        | 6377      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 118       |
# |    ep_rew_mean      | -1.71e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 244       |
# |    fps              | 1486      |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 26211     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.75      |
# |    n_updates        | 6527      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 122       |
# |    ep_rew_mean      | -1.79e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 248       |
# |    fps              | 1485      |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 26811     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.44      |
# |    n_updates        | 6677      |
# -----------------------------------
# MAX STEPS REACHED
# HIT!
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 123       |
# |    ep_rew_mean      | -1.78e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 252       |
# |    fps              | 1486      |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 27274     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.12      |
# |    n_updates        | 6793      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# HIT!
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 125       |
# |    ep_rew_mean      | -1.74e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 256       |
# |    fps              | 1486      |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 27797     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 33.9      |
# |    n_updates        | 6924      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 126       |
# |    ep_rew_mean      | -1.75e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 260       |
# |    fps              | 1485      |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 28301     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.13      |
# |    n_updates        | 7050      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 129       |
# |    ep_rew_mean      | -1.81e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 264       |
# |    fps              | 1486      |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 28901     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 18.2      |
# |    n_updates        | 7200      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 132       |
# |    ep_rew_mean      | -1.83e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 268       |
# |    fps              | 1487      |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 29501     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 34.1      |
# |    n_updates        | 7350      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 132       |
# |    ep_rew_mean      | -1.84e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 272       |
# |    fps              | 1488      |
# |    time_elapsed     | 20        |
# |    total_timesteps  | 30086     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.26      |
# |    n_updates        | 7496      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 131       |
# |    ep_rew_mean      | -1.86e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 276       |
# |    fps              | 1487      |
# |    time_elapsed     | 20        |
# |    total_timesteps  | 30463     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.31      |
# |    n_updates        | 7590      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 132       |
# |    ep_rew_mean      | -1.89e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 280       |
# |    fps              | 1485      |
# |    time_elapsed     | 20        |
# |    total_timesteps  | 30896     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 34.1      |
# |    n_updates        | 7698      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 132       |
# |    ep_rew_mean      | -1.93e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 284       |
# |    fps              | 1485      |
# |    time_elapsed     | 21        |
# |    total_timesteps  | 31437     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.8       |
# |    n_updates        | 7834      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 133       |
# |    ep_rew_mean      | -1.99e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 288       |
# |    fps              | 1485      |
# |    time_elapsed     | 21        |
# |    total_timesteps  | 31945     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.18      |
# |    n_updates        | 7961      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# HIT!
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 132       |
# |    ep_rew_mean      | -2.04e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 292       |
# |    fps              | 1485      |
# |    time_elapsed     | 21        |
# |    total_timesteps  | 32312     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.68      |
# |    n_updates        | 8052      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 134       |
# |    ep_rew_mean      | -2.14e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 296       |
# |    fps              | 1482      |
# |    time_elapsed     | 22        |
# |    total_timesteps  | 32912     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.79      |
# |    n_updates        | 8202      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 136       |
# |    ep_rew_mean      | -2.29e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 300       |
# |    fps              | 1479      |
# |    time_elapsed     | 22        |
# |    total_timesteps  | 33493     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 32.5      |
# |    n_updates        | 8348      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 137       |
# |    ep_rew_mean      | -2.35e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 304       |
# |    fps              | 1480      |
# |    time_elapsed     | 23        |
# |    total_timesteps  | 34055     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.65      |
# |    n_updates        | 8488      |
# -----------------------------------
# HIT!
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 134       |
# |    ep_rew_mean      | -2.27e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 308       |
# |    fps              | 1480      |
# |    time_elapsed     | 23        |
# |    total_timesteps  | 34433     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.43      |
# |    n_updates        | 8583      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 134       |
# |    ep_rew_mean      | -2.28e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 312       |
# |    fps              | 1480      |
# |    time_elapsed     | 23        |
# |    total_timesteps  | 34983     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.62      |
# |    n_updates        | 8720      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# HIT!
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 133       |
# |    ep_rew_mean      | -2.25e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 316       |
# |    fps              | 1480      |
# |    time_elapsed     | 23        |
# |    total_timesteps  | 35487     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36.1      |
# |    n_updates        | 8846      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 133       |
# |    ep_rew_mean      | -2.34e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 320       |
# |    fps              | 1480      |
# ...
# |    loss             | 84.8      |
# |    n_updates        | 175981    |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 97.6      |
# |    ep_rew_mean      | -1.41e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6568      |
# |    fps              | 1365      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 704553    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 31.3      |
# |    n_updates        | 176113    |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 97.3      |
# |    ep_rew_mean      | -1.41e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6572      |
# |    fps              | 1360      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 704905    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 60.5      |
# |    n_updates        | 176201    |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 98.8      |
# |    ep_rew_mean      | -1.42e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6576      |
# |    fps              | 1360      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 705377    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 59.7      |
# |    n_updates        | 176319    |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 100       |
# |    ep_rew_mean      | -1.42e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6580      |
# |    fps              | 1366      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 705872    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 24.8      |
# |    n_updates        | 176442    |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 102       |
# |    ep_rew_mean      | -1.46e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6584      |
# |    fps              | 1350      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 706425    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 20.2      |
# |    n_updates        | 176581    |
# -----------------------------------
# HIT!
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 101       |
# |    ep_rew_mean      | -1.43e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6588      |
# |    fps              | 1348      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 706702    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 21.4      |
# |    n_updates        | 176650    |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 101       |
# |    ep_rew_mean      | -1.38e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6592      |
# |    fps              | 1352      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 707147    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36        |
# |    n_updates        | 176761    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -1.4e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6596     |
# |    fps              | 1359     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 707575   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 42.2     |
# |    n_updates        | 176868   |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 100       |
# |    ep_rew_mean      | -1.37e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6600      |
# |    fps              | 1356      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 707874    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 27        |
# |    n_updates        | 176943    |
# -----------------------------------
# OUT OF BOUNDS
# HIT!
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 100       |
# |    ep_rew_mean      | -1.33e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6604      |
# |    fps              | 1353      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 708312    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 28.7      |
# |    n_updates        | 177052    |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 98.9      |
# |    ep_rew_mean      | -1.37e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6608      |
# |    fps              | 1352      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 708605    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 31.6      |
# |    n_updates        | 177126    |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 100       |
# |    ep_rew_mean      | -1.39e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6612      |
# |    fps              | 1351      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 709056    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 91.3      |
# |    n_updates        | 177238    |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 62
#      58 eval_interval = 100000  # Evaluate and log every 10000 steps
#      60 for step in range(0, total_timesteps, eval_interval):
#      61     # Train for a number of timesteps
# ---> 62     model.learn(total_timesteps=eval_interval, reset_num_timesteps=False)
#      64     # Run an evaluation episode
#      65     episode_length, episode_reward, out_of_bounds, interceptions, reached_max_steps = run_episode(env, model)
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\dqn\dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:557, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     554     self.actor.reset_noise(env.num_envs)
#     556 # Select action randomly or according to policy
# --> 557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
#     560 new_obs, rewards, dones, infos = env.step(actions)
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:390, in OffPolicyAlgorithm._sample_action(self, learning_starts, action_noise, n_envs)
#     385 else:
#     386     # Note: when using continuous actions,
#     387     # we assume that the policy uses tanh to scale the action
#     388     # We use non-deterministic action in the case of SAC, for TD3, it does not matter
#     389     assert self._last_obs is not None, "self._last_obs was not set"
# --> 390     unscaled_action, _ = self.predict(self._last_obs, deterministic=False)
#     392 # Rescale the action from [low, high] to [-1, 1]
#     393 if isinstance(self.action_space, spaces.Box):
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\dqn\dqn.py:255, in DQN.predict(self, observation, state, episode_start, deterministic)
#     253         action = np.array(self.action_space.sample())
#     254 else:
# --> 255     action, state = self.policy.predict(observation, state, episode_start, deterministic)
#     256 return action, state
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\dqn\policies.py:184, in DQNPolicy._predict(self, obs, deterministic)
#     183 def _predict(self, obs: PyTorchObs, deterministic: bool = True) -> th.Tensor:
# --> 184     return self.q_net._predict(obs, deterministic=deterministic)
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\dqn\policies.py:69, in QNetwork._predict(self, observation, deterministic)
#      68 def _predict(self, observation: PyTorchObs, deterministic: bool = True) -> th.Tensor:
# ---> 69     q_values = self(observation)
#      70     # Greedy action
#      71     action = q_values.argmax(dim=1).reshape(-1)
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\dqn\policies.py:66, in QNetwork.forward(self, obs)
#      59 def forward(self, obs: PyTorchObs) -> th.Tensor:
#      60     """
#      61     Predict the q-values.
#      62
#      63     :param obs: Observation
#      64     :return: The estimated Q-Value for each action.
#      65     """
# ---> 66     return self.q_net(self.extract_features(obs, self.features_extractor))
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\policies.py:131, in BaseModel.extract_features(self, obs, features_extractor)
#     123 """
#     124 Preprocess the observation if needed and extract features.
#     125
#    (...)
#     128 :return: The extracted features
#     129 """
#     130 preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 131 return features_extractor(preprocessed_obs)
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\torch_layers.py:45, in FlattenExtractor.forward(self, observations)
#      44 def forward(self, observations: th.Tensor) -> th.Tensor:
# ---> 45     return self.flatten(observations)
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\flatten.py:46, in Flatten.forward(self, input)
#      45 def forward(self, input: Tensor) -> Tensor:
# ---> 46     return input.flatten(self.start_dim, self.end_dim)
#
# KeyboardInterrupt:
