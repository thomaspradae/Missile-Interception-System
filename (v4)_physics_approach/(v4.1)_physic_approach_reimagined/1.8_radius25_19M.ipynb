# %%
import gymnasium as gym
import numpy as np

class missile_interception_3d(gym.Env):
    def __init__(self, enemy_mode="ballistic"):
        assert enemy_mode in ("ballistic", "static")
        self.enemy_mode = enemy_mode

        # 1. Define Action Space: magnitude + direction on unit circle (cos, sin)
        self.action_space = gym.spaces.Box(low=-1.0, high=1.0, shape=(3,), dtype=np.float32)
        
        # 2. Define Observation Space (16D ego-frame, no actuator state)
        self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(16,), dtype=np.float32)

        self.np_random = np.random.RandomState()
        
        # 3. Time Settings
        self.dt_act = 0.1             
        self.n_substeps = 1      
        self.dt_sim = self.dt_act / self.n_substeps 
        self.t_max = 40.0
        self.episode_cap_time = 40.0   # shorter episodes for PPO stability

        # 4. Physical Limits
        self.a_max = 350.0   # Max G-force (m/s^2) ~35G
        self.g = 9.81        
        self.collision_radius = 25.0   # easier for sparse learning

        # Small geometry so sparse RL can bootstrap (random success plausible)
        self.p_easy = 1.0                   
        self.range_min = 800.0           
        self.range_easy_max = 2500.0     
        self.range_hard_max = 2500.0

        self.targetbox_x_min = -5000
        self.targetbox_x_max = 5000
        self.targetbox_y_min = -5000
        self.targetbox_y_max = 5000

        # ---- New ZEM reward parameters ----
        self.d_scale = 100.0      # will tune later using ProNav statistics
        self.v_scale = 1000.0
        self.eta_close = 0.1

        self.r_hit_bonus = 25.0
        self.r_timeout_pen = 25.0
        self.r_enemy_ground_pen = 25.0
        self.r_def_ground_pen = 40.0

        # episode diagnostics (no thresholds)
        self.ep_dca_pos_steps = 0          # count(delta_dca > 0)
        self.ep_vclose_pos_steps = 0       # count(v_close > 0)

    def generate_enemy_missile(self):
        if self.np_random.rand() < self.p_easy:
            self.range_max_used = self.range_easy_max
        else:
            self.range_max_used = self.range_hard_max

        range_min = self.range_min
        self.attack_target_x = self.np_random.uniform(self.targetbox_x_min, self.targetbox_x_max)
        self.attack_target_y = self.np_random.uniform(self.targetbox_y_min, self.targetbox_y_max)
        self.enemy_launch_angle = self.np_random.uniform(0, 2 * np.pi)
        self.enemy_theta = self.np_random.uniform(0.523599, 1.0472) 

        self.range_max_used = max(self.range_max_used, range_min + 1.0)
        lower_limit = np.sqrt((range_min * self.g) / np.sin(2 * self.enemy_theta))
        upper_limit = np.sqrt((self.range_max_used * self.g) / np.sin(2 * self.enemy_theta))
        self.enemy_initial_velocity = self.np_random.uniform(lower_limit, upper_limit)
        self.enemy_initial_velocity = float(np.clip(self.enemy_initial_velocity, 700.0, 1100.0))

        ground_range = (
            self.enemy_initial_velocity * np.cos(self.enemy_theta)
            * (2 * self.enemy_initial_velocity * np.sin(self.enemy_theta) / self.g)
        )

        self.enemy_launch_x = self.attack_target_x + ground_range * np.cos(self.enemy_launch_angle)
        self.enemy_launch_y = self.attack_target_y + ground_range * np.sin(self.enemy_launch_angle)
        self.enemy_z = 0
        self.enemy_x = self.enemy_launch_x
        self.enemy_y = self.enemy_launch_y
        self.enemy_pos = np.array([self.enemy_x, self.enemy_y, self.enemy_z], dtype=np.float32)
        self.enemy_azimuth = (self.enemy_launch_angle + np.pi) % (2 * np.pi)

        if self.enemy_mode == "static":
            # Freeze enemy at a random mid-flight point of its ballistic trajectory
            vel0 = np.array([
                self.enemy_initial_velocity * np.cos(self.enemy_azimuth) * np.cos(self.enemy_theta),
                self.enemy_initial_velocity * np.sin(self.enemy_azimuth) * np.cos(self.enemy_theta),
                self.enemy_initial_velocity * np.sin(self.enemy_theta),
            ], dtype=np.float64)
            g_vec = np.array([0.0, 0.0, -self.g], dtype=np.float64)
            t_flight = 2.0 * self.enemy_initial_velocity * np.sin(self.enemy_theta) / self.g
            t_sample = self.np_random.uniform(0.25, 0.75) * t_flight
            pos0 = self.enemy_pos.astype(np.float64)
            self.enemy_pos = (pos0 + vel0 * t_sample + 0.5 * g_vec * (t_sample ** 2)).astype(np.float32)
            self.enemy_x, self.enemy_y, self.enemy_z = self.enemy_pos

    def generate_defense_missile(self):
        self.defense_launch_x = self.np_random.uniform(self.targetbox_x_min, self.targetbox_x_max)
        self.defense_launch_y = self.np_random.uniform(self.targetbox_y_min, self.targetbox_y_max)

        dx = self.enemy_x - self.defense_launch_x
        dy = self.enemy_y - self.defense_launch_y
        az_nominal = np.arctan2(dy, dx)
        self.az_nominal = az_nominal

        # --- Misalignment: interceptor initially points roughly toward target ---
        az_noise_deg = 5.0
        az_noise = self.np_random.uniform(-np.deg2rad(az_noise_deg), +np.deg2rad(az_noise_deg))
        self.defense_azimuth = az_nominal + az_noise

        self.defense_theta = np.deg2rad(45.0)

        base_velocity = 1200.0
        self.defense_initial_velocity = base_velocity

        self.defense_x = self.defense_launch_x
        self.defense_y = self.defense_launch_y
        self.defense_z = 0.0
        self.defense_pos = np.array([self.defense_x, self.defense_y, self.defense_z], dtype=np.float32)
    
    def _smoothstep(self, x: float) -> float:
        """Smooth ramp 0->1 with zero slope at ends, clamps outside [0,1]"""
        x = float(np.clip(x, 0.0, 1.0))
        return x * x * (3.0 - 2.0 * x)

    def _decode_action(self, a):
        """
        a = [m_raw, c_raw, s_raw] in [-1,1]^3
        Returns: (u_right, u_up) in [-1,1] with sqrt(u_right^2 + u_up^2) <= 1
        """
        a = np.asarray(a, dtype=np.float32)
        m_raw, c_raw, s_raw = float(a[0]), float(a[1]), float(a[2])

        m = 0.5 * (m_raw + 1.0)   # [-1,1] -> [0,1]

        v = np.array([c_raw, s_raw], dtype=np.float32)
        n = float(np.linalg.norm(v))
        if n < 1e-6:
            dir2 = np.array([1.0, 0.0], dtype=np.float32)
        else:
            dir2 = v / n

        u_right = float(m * dir2[0])
        u_up    = float(m * dir2[1])
        return np.array([u_right, u_up], dtype=np.float32)

    def calculate_pronav(self):
        eps = 1e-9

        # Relative geometry (use float64 for stability)
        r = (self.enemy_pos - self.defense_pos).astype(np.float64)
        v = self.defense_vel.astype(np.float64)
        vrel = (self.enemy_vel - self.defense_vel).astype(np.float64)

        R = float(np.linalg.norm(r)) + eps
        V = float(np.linalg.norm(v)) + eps

        rhat = r / R
        vhat = v / V

        # Heading error alpha = angle between velocity direction and LOS direction
        cosang = float(np.clip(np.dot(vhat, rhat), -1.0, 1.0))
        alpha = float(np.arccos(cosang))  # radians

        # LOS angular rate omega (world frame)
        omega = np.cross(r, vrel) / (float(np.dot(r, r)) + eps)
        omega_mag = float(np.linalg.norm(omega))

        # Closing speed (positive => closing)
        vc = -float(np.dot(r, vrel)) / R

        # --- PN term ---
        N = 3.0
        a_pn = N * vc * np.cross(omega, rhat)  # lateral accel in world frame

        # --- Acquisition term (turn-to-LOS) ---
        # Perpendicular component of LOS relative to forward direction
        rhat_perp = rhat - float(np.dot(rhat, vhat)) * vhat
        nperp = float(np.linalg.norm(rhat_perp))

        if nperp < 1e-8:
            a_acq = np.zeros(3, dtype=np.float64)
        else:
            rhat_perp /= nperp  # unit sideways "turn toward LOS" direction

            # Curvature-based magnitude: ~k * V^2 / R, saturate later via a_max
            k_acq = 5.0  # try 3.0–8.0
            a_acq = k_acq * (V * V / R) * rhat_perp

        # --- Blend weight w: 0 => pure PN, 1 => pure acquisition ---

        # Alpha-based weight (dominant)
        alpha_on   = np.deg2rad(20.0)   # start blending earlier
        alpha_full = np.deg2rad(55.0)

        x_alpha = (alpha - alpha_on) / (alpha_full - alpha_on + eps)
        w_alpha = self._smoothstep(x_alpha)

        # Omega-based modifier (only boosts acquisition when PN is sleepy)
        omega_full = 0.00
        omega_on   = 0.05   # <-- key: less brittle than 0.02

        x_omega = (omega_on - omega_mag) / (omega_on - omega_full + eps)
        w_omega = self._smoothstep(x_omega)

        # Robust combine: alpha dominates; omega can't fully shut it off
        w = w_alpha * (0.25 + 0.75 * w_omega)

        # Optional: if not closing, force strong acquisition
        if vc <= 0.0:
            w = max(w, 0.9)

        a_ideal = (1.0 - w) * a_pn + w * a_acq

        # Project into your lateral control basis (right/up) and normalize by a_max
        # Action is lateral body acceleration; gravity applies as world force.
        # so ProNav outputs desired NET lateral accel (same semantics as PPO)
        forward, right, up = self._compute_lateral_basis(self.defense_vel)
        a_right = float(np.dot(a_ideal, right))
        a_up    = float(np.dot(a_ideal, up))

        u_raw = np.array([a_right / self.a_max, a_up / self.a_max], dtype=np.float32)
        self._pronav_u_raw = u_raw.copy()
        u = np.clip(u_raw, -1.0, 1.0)
        return pronav_to_polar_action(float(u[0]), float(u[1]))
    
    def _segment_sphere_intersect(self, r0, r1, r_hit):
        dr = r1 - r0
        dr_norm_sq = float(np.dot(dr, dr))
        if dr_norm_sq < 1e-12:
            return float(np.dot(r0, r0)) <= r_hit * r_hit
        s_star = -float(np.dot(r0, dr)) / dr_norm_sq
        s_star = max(0.0, min(1.0, s_star))
        r_closest = r0 + s_star * dr
        return float(np.dot(r_closest, r_closest)) <= r_hit * r_hit
    
    def _get_obs(self):
        eps = 1e-9

        # World-frame relative state
        r_world = (self.enemy_pos - self.defense_pos).astype(np.float64)
        vrel_world = (self.enemy_vel - self.defense_vel).astype(np.float64)

        # Local basis from defense velocity (world frame unit vectors)
        forward, right, up = self._compute_lateral_basis(self.defense_vel)

        # ===============================
        # 1) Ego-frame (body-frame) r and vrel
        # ===============================
        r_body = np.array([
            float(np.dot(r_world, forward)),
            float(np.dot(r_world, right)),
            float(np.dot(r_world, up)),
        ], dtype=np.float64)

        vrel_body = np.array([
            float(np.dot(vrel_world, forward)),
            float(np.dot(vrel_world, right)),
            float(np.dot(vrel_world, up)),
        ], dtype=np.float64)

        # Normalize r_body / vrel_body
        pos_scale = float(self.range_easy_max)   # 10 km
        vel_scale = 2500.0                        # max vrel ~2300 m/s in Stage-1

        r_body_n = (r_body / (pos_scale + eps)).astype(np.float32)
        vrel_body_n = (vrel_body / (vel_scale + eps)).astype(np.float32)

        # ===============================
        # 2) Scalar helpers
        # ===============================
        dist = float(np.linalg.norm(r_world)) + 1e-6
        v_close = -float(np.dot(r_world, vrel_world)) / dist  # positive when closing

        dist_n = np.float32(np.clip(dist / 50_000.0, 0.0, 4.0))
        vclose_n = np.float32(np.clip(v_close / 2000.0, -2.0, 2.0))
        dist_vclose_feat = np.array([dist_n, vclose_n], dtype=np.float32)

        # Defense own vertical state (keep for ground constraint)
        def_z_n = np.float32(np.clip(self.defense_pos[2] / 15_000.0, -1.0, 2.0))
        def_vz_n = np.float32(np.clip(self.defense_vel[2] / 1200.0, -2.0, 2.0))
        def_state_feat = np.array([def_z_n, def_vz_n], dtype=np.float32)

        # ===============================
        # 4) Keep your geometry features (consistent with ego-frame)
        # ===============================
        dist_body = float(np.linalg.norm(r_body)) + 1e-6

        # LOS lateral projections in body frame
        los_right = float(r_body[1] / dist_body)
        los_up    = float(r_body[2] / dist_body)

        # LOS rate omega in body frame: omega = (r x vrel)/||r||^2
        dist2_body = float(np.dot(r_body, r_body)) + eps
        omega_body = np.cross(r_body, vrel_body) / dist2_body

        omega_right = float(omega_body[1])
        omega_up    = float(omega_body[2])

        omega_scale = 2.0
        omega_right_n = float(np.clip(omega_right / omega_scale, -2.0, 2.0))
        omega_up_n    = float(np.clip(omega_up / omega_scale, -2.0, 2.0))

        geom_feat = np.array([los_right, los_up, omega_right_n, omega_up_n], dtype=np.float32)

        # ===============================
        # 5) NEW: kinematics garnish
        # ===============================
        V_def = float(np.linalg.norm(self.defense_vel))
        V_def_n = np.float32(np.clip(V_def / 1500.0, 0.0, 3.0))
        forward_z = np.float32(float(forward[2]))               # dot(forward, world_up) since world_up=[0,0,1]

        kin_feat = np.array([V_def_n, forward_z], dtype=np.float32)

        # Final obs (16D, no actuator state)
        obs = np.concatenate(
            [r_body_n, vrel_body_n, dist_vclose_feat, def_state_feat, geom_feat, kin_feat],
            axis=0
        ).astype(np.float32)

        return obs

    def _compute_lateral_basis(self, velocity):
        """
        Horizon-stable basis:
          forward = along velocity
          right   = world_up x forward  (horizontal right)
          up      = forward x right     (completes orthonormal frame)
        This keeps 'up' as close to world-up as possible and avoids weird twisting.
        """
        speed = float(np.linalg.norm(velocity))
        if speed < 1.0:
            forward = np.array([1.0, 0.0, 0.0], dtype=np.float32)
        else:
            forward = (velocity / speed).astype(np.float32)

        world_up = np.array([0.0, 0.0, 1.0], dtype=np.float32)

        # right = world_up x forward
        right_raw = np.cross(world_up, forward)
        rnorm = float(np.linalg.norm(right_raw))

        # If forward is near world_up, right_raw ~ 0. Pick a consistent fallback.
        if rnorm < 1e-6:
            # Choose a fixed "north" axis in world XY and build right from that
            # This prevents random spinning when vertical.
            north = np.array([1.0, 0.0, 0.0], dtype=np.float32)
            right_raw = np.cross(north, forward)
            rnorm = float(np.linalg.norm(right_raw))
            if rnorm < 1e-6:
                north = np.array([0.0, 1.0, 0.0], dtype=np.float32)
                right_raw = np.cross(north, forward)
                rnorm = float(np.linalg.norm(right_raw))

        right = (right_raw / (rnorm + 1e-9)).astype(np.float32)

        # up = forward x right (not right x forward)
        up_raw = np.cross(forward, right)
        up = (up_raw / (float(np.linalg.norm(up_raw)) + 1e-9)).astype(np.float32)

        return forward, right, up

    def step(self, action):
        if getattr(self, "done", False):
            return self._get_obs(), 0.0, True, False, {"event": "called_step_after_done", "dist": float(np.linalg.norm(self.enemy_pos - self.defense_pos)), "mag_exec": float(np.nan)}
        
        action = np.clip(action, -1.0, 1.0).astype(np.float32)
        action2 = self._decode_action(action)  # 3D polar -> 2D (right, up), ||.|| <= 1
        mag_exec = float(np.linalg.norm(action2))
        assert mag_exec <= 1.0001, f"_decode_action broke invariant: ||action2|| = {mag_exec}"
        
        # Update episode trackers
        self.ep_max_action_mag = max(self.ep_max_action_mag, mag_exec)

        terminated = False
        truncated = False
        event = "running"
        
        for _ in range(self.n_substeps):
            dt = self.dt_sim
            enemy_pos_old = self.enemy_pos.copy()
            defense_pos_old = self.defense_pos.copy()
            
            forward, right, up = self._compute_lateral_basis(self.defense_vel)
            g_vec = np.array([0.0, 0.0, -self.g], dtype=np.float32)

            # Pure commanded acceleration in body right/up
            a_cmd = (action2[0] * self.a_max) * right + (action2[1] * self.a_max) * up

            # Physics: command + gravity
            self.defense_vel += (a_cmd + g_vec) * dt
            self.defense_pos += self.defense_vel * dt
            self.defense_x, self.defense_y, self.defense_z = self.defense_pos
            
            # Enemy missile: ballistic (gravity only) OR frozen (static mode)
            if self.enemy_mode == "ballistic":
                self.enemy_vel += g_vec * dt
                self.enemy_pos += self.enemy_vel * dt
                self.enemy_x, self.enemy_y, self.enemy_z = self.enemy_pos
            self.t += dt
            
            r0 = enemy_pos_old - defense_pos_old
            r1 = self.enemy_pos - self.defense_pos

            # Closest point along segment (same geometry as hit detector)
            dr = r1 - r0
            dr_norm_sq = np.dot(dr, dr)
            if dr_norm_sq > 1e-12:
                s_star = -np.dot(r0, dr) / dr_norm_sq
                s_star = np.clip(s_star, 0.0, 1.0)
                r_closest = r0 + s_star * dr
                dist_seg = np.linalg.norm(r_closest)
            else:
                dist_seg = np.linalg.norm(r0)
            self.ep_min_dist = min(self.ep_min_dist, float(dist_seg))

            if self._segment_sphere_intersect(r0, r1, self.collision_radius):
                self.success = True
                terminated = True
                self.done = True
                event = "hit"
                self.time_to_hit = float(self.t)
                self.terminal_event = "hit"
                break
            
            # --- Only real physics terminals ---
            if self.defense_pos[2] < 0.0:
                terminated = True
                self.done = True
                event = "defense_ground"
                self.terminal_event = event
                break

            if self.enemy_mode == "ballistic" and self.enemy_pos[2] < 0.0:
                terminated = True
                self.done = True
                event = "enemy_ground"
                self.terminal_event = event
                break

            if self.enemy_mode == "static" and self.t >= self.episode_cap_time:
                truncated = True
                self.done = True
                event = "episode_cap"
                self.terminal_event = event
                break

            # --- Debug safety fuse (not a "task" terminal) ---
            if self.t >= self.t_max:
                truncated = True
                self.done = True
                event = "debug_cap"
                self.terminal_event = event
                break

        obs = self._get_obs()
        dist_after = float(np.linalg.norm(self.enemy_pos - self.defense_pos))
        self.min_dist = min(getattr(self, "min_dist", float("inf")), dist_after)

        # ==========================
        # Range delta (real geometry)
        # ==========================
        if getattr(self, "prev_dist", None) is None:
            dist_prev = dist_after
        else:
            dist_prev = float(self.prev_dist)

        delta_dist = dist_prev - dist_after  # >0 means we got closer in real range
        self.prev_dist = dist_after

        # ==========================================
        # ZEM-style geometry reward (with debug)
        # ==========================================
        eps = 1e-9
        r = (self.enemy_pos - self.defense_pos).astype(np.float64)
        vrel = (self.enemy_vel - self.defense_vel).astype(np.float64)

        r_norm = float(np.linalg.norm(r)) + eps
        r_norm_sq = float(np.dot(r, r)) + eps
        vrel_norm_sq = float(np.dot(vrel, vrel)) + eps
        dot_r_v = float(np.dot(r, vrel))

        # Raw time-to-closest-approach (can be <0 or huge)
        t_star_raw = -dot_r_v / vrel_norm_sq

        # Clip horizon
        t_cap = 10.0
        t_star_clipped = float(np.clip(t_star_raw, 0.0, t_cap))

        hit_t0   = (t_star_raw <= 0.0)
        hit_tcap = (t_star_raw >= t_cap)

        # Predicted closest approach vector and distance
        r_star = r + vrel * t_star_clipped
        d_ca = float(np.linalg.norm(r_star))

        # Previous d_ca (for delta)
        if self.prev_d_ca is None:
            d_ca_prev = d_ca
        else:
            d_ca_prev = float(self.prev_d_ca)

        delta_dca = d_ca_prev - d_ca
        self.prev_d_ca = d_ca

        # Count "did d_ca improve at all?"
        if delta_dca > 0.0:
            self.ep_dca_pos_steps += 1

        self.ep_total_steps += 1

        # LOS angular rate (world)
        omega_world = np.cross(r, vrel) / r_norm_sq
        omega_mag = float(np.linalg.norm(omega_world))

        # Closing speed (positive is closing)
        v_close = -dot_r_v / r_norm

        # Count "are we closing at all?"
        if v_close > 0.0:
            self.ep_vclose_pos_steps += 1

        if t_star_clipped < 2.0:
            self.ep_omega_terminal_samples.append(omega_mag)

        # ======================================
        # SPARSE TERMINAL REWARD ONLY (hit=+1, else=0)
        # No penalties — maximize P(hit)
        # ======================================
        reward = 1.0 if event == "hit" else 0.0

        if terminated or truncated:
            self.terminal_event = event

        steps = self.ep_total_steps
        dca_pos_ratio = (self.ep_dca_pos_steps / steps) if steps > 0 else 0.0
        vclose_pos_ratio = (self.ep_vclose_pos_steps / steps) if steps > 0 else 0.0

        v_def = self.defense_vel.astype(np.float64)
        V_def = float(np.linalg.norm(v_def)) + 1e-9
        fwd_z = float(self._compute_lateral_basis(self.defense_vel)[0][2])

        info = {
            "event": event,
            "t": float(self.t),
            "dist": float(dist_after),
            "closing": float(v_close),
            "reward": float(reward),
            "mag_exec": float(mag_exec),
            "defense_z": float(self.defense_pos[2]),
            "defense_vz": float(self.defense_vel[2]),
            "defense_speed": float(V_def),
            "forward_z": float(fwd_z),
            "delta_dca": float(delta_dca),
            "dca_pos_steps": int(self.ep_dca_pos_steps),
            "dca_pos_ratio": float(dca_pos_ratio),
            "vclose_pos_steps": int(self.ep_vclose_pos_steps),
            "vclose_pos_ratio": float(vclose_pos_ratio),
            "d_ca": float(d_ca),
            "t_star": float(t_star_clipped),
        }
        info.update({
            "dist_prev": float(dist_prev),
            "delta_dist": float(delta_dist),
            "t_cap": float(t_cap),
            "t_star_raw": float(t_star_raw),
            "t_star_hit0": bool(hit_t0),
            "t_star_hitcap": bool(hit_tcap),
            "dot_r_vrel": float(dot_r_v),
            "vrel_norm_sq": float(vrel_norm_sq),
            "r_norm": float(r_norm),
            "omega_mag": float(omega_mag),
            "r_star_x": float(r_star[0]),
            "r_star_y": float(r_star[1]),
            "r_star_z": float(r_star[2]),
        })
        if terminated or truncated:
            d_min = float(self.ep_min_dist)
            hit = (event == "hit")
            info["hit"] = hit
            info["miss_distance"] = d_min
            info["min_dist"] = d_min
            info["max_action_mag"] = float(self.ep_max_action_mag)
            info["time_to_hit"] = float(self.time_to_hit) if self.time_to_hit is not None else np.nan
            info["los_terminal_p95"] = float(np.percentile(self.ep_omega_terminal_samples, 95)) if self.ep_omega_terminal_samples else np.nan
        return obs, reward, terminated, truncated, info

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        if seed is not None: self.np_random = np.random.RandomState(seed)
        self.done = False
        self.success = False
        self.t = 0.0
        self.generate_enemy_missile()
        self.generate_defense_missile()
        
        self.defense_vel = np.array([
            self.defense_initial_velocity * np.cos(self.defense_azimuth) * np.cos(self.defense_theta),
            self.defense_initial_velocity * np.sin(self.defense_azimuth) * np.cos(self.defense_theta),
            self.defense_initial_velocity * np.sin(self.defense_theta)
        ], dtype=np.float32)
        
        if self.enemy_mode == "ballistic":
            self.enemy_vel = np.array([
                self.enemy_initial_velocity * np.cos(self.enemy_azimuth) * np.cos(self.enemy_theta),
                self.enemy_initial_velocity * np.sin(self.enemy_azimuth) * np.cos(self.enemy_theta),
                self.enemy_initial_velocity * np.sin(self.enemy_theta)
            ], dtype=np.float32)
        else:
            self.enemy_vel = np.zeros(3, dtype=np.float32)
        
        self.defense_pos = np.array([self.defense_x, self.defense_y, self.defense_z], dtype=np.float32)

        # enemy_pos: ballistic = rebuild from launch coords; static = keep mid-flight sample from generate_enemy_missile
        if self.enemy_mode == "ballistic":
            self.enemy_pos = np.array([self.enemy_x, self.enemy_y, self.enemy_z], dtype=np.float32)
        else:
            self.enemy_x, self.enemy_y, self.enemy_z = self.enemy_pos

        d0 = float(np.linalg.norm(self.enemy_pos - self.defense_pos))
        Vd = float(np.linalg.norm(self.defense_vel)) + 1e-6
        if self.enemy_mode == "static":
            self.t_max = self.episode_cap_time
        else:
            self.t_max = min(40.0, 3.0 * d0 / Vd)
        self.min_dist = d0
        self.ep_min_dist = d0
        self.ep_max_action_mag = 0.0
        self.time_to_hit = None
        self.terminal_event = "running"
        self.prev_d_ca = None
        self.prev_dist = None
        self.ep_dca_pos_steps = 0
        self.ep_vclose_pos_steps = 0
        self.ep_total_steps = 0
        self.ep_omega_terminal_samples = []
        
        return self._get_obs(), {}


def pronav_to_polar_action(u_right, u_up):
    """Convert old-style 2D (right, up) action to new 3D polar (m_raw, c_raw, s_raw)."""
    u = np.array([u_right, u_up], dtype=np.float32)
    m = float(np.linalg.norm(u))
    if m < 1e-6:
        return np.array([-1.0, 1.0, 0.0], dtype=np.float32)  # magnitude 0, arbitrary direction
    dir2 = u / m
    m = min(m, 1.0)
    m_raw = 2.0 * m - 1.0  # [0,1] -> [-1,1]
    return np.array([m_raw, float(dir2[0]), float(dir2[1])], dtype=np.float32)


# ==========================================
# EVALUATION FUNCTION (separate from training reward)
# ==========================================
def evaluate_policy(env, policy_fn, n_episodes=100, seed0=0):
    """
    Evaluate a policy and return episode-level metrics.
    This is separate from training reward - these metrics are what you actually care about.
    
    Args:
        env: missile_interception_3d environment instance
        policy_fn: Function that takes obs and returns action
        n_episodes: Number of episodes to evaluate
        seed0: Starting seed (episodes use seed0, seed0+1, ..., seed0+n_episodes-1)
    
    Returns:
        summary: Dict with aggregated metrics (hit_rate, min_dist stats, etc.)
        metrics: Dict with raw episode data
    """
    metrics = {
        "hits": 0,
        "ground_defense": 0,
        "ground_enemy": 0,
        "episode_cap": 0,
        "debug_cap": 0,
        "min_dist_list": [],
        "time_to_hit_list": [],
        "max_g_list": [],
        "dca_pos_ratio_list": [],
        "vclose_pos_ratio_list": [],
        "los_terminal_p95_list": [],
    }

    for i in range(n_episodes):
        obs, _ = env.reset(seed=seed0 + i)
        done = False

        while not done:
            action = policy_fn(obs)  # your PPO policy OR env.calculate_pronav() baseline
            obs, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

        event = info["event"]
        metrics["min_dist_list"].append(env.ep_min_dist)
        metrics["max_g_list"].append(env.ep_max_action_mag)
        metrics["dca_pos_ratio_list"].append(info["dca_pos_ratio"])
        metrics["vclose_pos_ratio_list"].append(info["vclose_pos_ratio"])
        if "los_terminal_p95" in info and np.isfinite(info.get("los_terminal_p95", np.nan)):
            metrics["los_terminal_p95_list"].append(info["los_terminal_p95"])

        if event == "hit":
            metrics["hits"] += 1
            if env.time_to_hit is not None:
                metrics["time_to_hit_list"].append(env.time_to_hit)
        elif event == "defense_ground":
            metrics["ground_defense"] += 1
        elif event == "enemy_ground":
            metrics["ground_enemy"] += 1
        elif event == "episode_cap":
            metrics["episode_cap"] += 1
        elif event == "debug_cap":
            metrics["debug_cap"] += 1

    hit_rate = metrics["hits"] / n_episodes

    summary = {
        "hit_rate": hit_rate,
        "min_dist_mean": float(np.mean(metrics["min_dist_list"])),
        "min_dist_p50": float(np.median(metrics["min_dist_list"])),
        "min_dist_p10": float(np.percentile(metrics["min_dist_list"], 10)),
        "time_to_hit_mean": float(np.mean(metrics["time_to_hit_list"])) if metrics["time_to_hit_list"] else None,
        "max_g_mean": float(np.mean(metrics["max_g_list"])),
        "dca_pos_ratio_mean": float(np.mean(metrics["dca_pos_ratio_list"])),
        "vclose_pos_ratio_mean": float(np.mean(metrics["vclose_pos_ratio_list"])),
        "los_terminal_p95_mean": float(np.mean(metrics["los_terminal_p95_list"])) if metrics["los_terminal_p95_list"] else np.nan,
        "violations": {
            "defense_ground": metrics["ground_defense"],
            "enemy_ground": metrics["ground_enemy"],
            "episode_cap": metrics["episode_cap"],
            "debug_cap": metrics["debug_cap"],
        }
    }
    return summary, metrics

def run_baseline(n_episodes=20, seed0=0):
    env = missile_interception_3d(enemy_mode="static")
    policy_fn = lambda obs: env.calculate_pronav()

    min_dist_list = []
    dca_pos_list = []
    vclose_pos_list = []
    los_terminal_p95_list = []
    hits = 0

    print(f"Running {n_episodes} episodes of Augmented ProNav...\n")

    for i in range(n_episodes):
        obs, _ = env.reset(seed=seed0 + i)
        done = False
        while not done:
            action = policy_fn(obs)
            obs, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

        event = info["event"]
        min_dist_list.append(env.ep_min_dist)
        dca_pos_list.append(info["dca_pos_ratio"])
        vclose_pos_list.append(info["vclose_pos_ratio"])
        if "los_terminal_p95" in info and np.isfinite(info.get("los_terminal_p95", np.nan)):
            los_terminal_p95_list.append(info["los_terminal_p95"])
        if event == "hit":
            hits += 1

        print(f"Ep {i+1:02d} | {event:<14} | minD {env.ep_min_dist:6.1f}m | dca_pos {info['dca_pos_ratio']:.3f} | vclose_pos {info['vclose_pos_ratio']:.3f} | los_p95 {info.get('los_terminal_p95', np.nan):.4f}")

    min_dist_list = np.array(min_dist_list)
    dca_pos_list = np.array(dca_pos_list)
    vclose_pos_list = np.array(vclose_pos_list)

    print(f"\n--- SUMMARY ({n_episodes} eps) ---")
    print(f"Hit Rate:            {hits}/{n_episodes} ({hits/n_episodes*100:.1f}%)")
    print(f"min_dist mean:       {float(np.mean(min_dist_list)):.1f} m")
    print(f"min_dist p50:        {float(np.median(min_dist_list)):.1f} m")
    print(f"min_dist p10:        {float(np.percentile(min_dist_list, 10)):.1f} m")
    print(f"dca_pos_ratio_mean:  {float(np.mean(dca_pos_list)):.3f}")
    print(f"vclose_pos_ratio_mean: {float(np.mean(vclose_pos_list)):.3f}")
    if los_terminal_p95_list:
        print(f"los_terminal_p95_mean: {float(np.mean(los_terminal_p95_list)):.4f}")

if __name__ == "__main__":
    run_baseline()
# Out:
# Running 20 episodes of Augmented ProNav...
#
# Ep 01 | hit            | minD    0.0m | dca_pos 0.879 | vclose_pos 0.996 | los_p95 0.0076
# Ep 02 | hit            | minD    8.4m | dca_pos 0.907 | vclose_pos 1.000 | los_p95 0.0095
# Ep 03 | hit            | minD    0.0m | dca_pos 0.956 | vclose_pos 0.997 | los_p95 0.0078
# Ep 04 | hit            | minD    0.1m | dca_pos 0.908 | vclose_pos 0.996 | los_p95 0.0072
# Ep 05 | hit            | minD    0.0m | dca_pos 0.983 | vclose_pos 0.991 | los_p95 0.0065
# Ep 06 | hit            | minD   23.9m | dca_pos 0.889 | vclose_pos 1.000 | los_p95 0.0073
# Ep 07 | hit            | minD    0.1m | dca_pos 0.902 | vclose_pos 0.995 | los_p95 0.0073
# Ep 08 | hit            | minD    0.0m | dca_pos 0.992 | vclose_pos 0.996 | los_p95 0.0060
# Ep 09 | hit            | minD    0.0m | dca_pos 0.889 | vclose_pos 0.995 | los_p95 0.0071
# Ep 10 | hit            | minD    0.0m | dca_pos 0.895 | vclose_pos 0.996 | los_p95 0.0075
# Ep 11 | hit            | minD   17.1m | dca_pos 0.891 | vclose_pos 1.000 | los_p95 0.0083
# Ep 12 | hit            | minD   20.0m | dca_pos 0.980 | vclose_pos 1.000 | los_p95 0.0082
# Ep 13 | hit            | minD    0.1m | dca_pos 0.926 | vclose_pos 0.991 | los_p95 0.0075
# Ep 14 | hit            | minD    0.0m | dca_pos 0.990 | vclose_pos 0.995 | los_p95 0.0049
# Ep 15 | hit            | minD    0.0m | dca_pos 0.890 | vclose_pos 0.996 | los_p95 0.0076
# Ep 16 | hit            | minD    0.0m | dca_pos 0.894 | vclose_pos 0.996 | los_p95 0.0076
# Ep 17 | hit            | minD    0.0m | dca_pos 0.900 | vclose_pos 0.996 | los_p95 0.0074
# Ep 18 | hit            | minD    0.0m | dca_pos 0.918 | vclose_pos 0.996 | los_p95 0.0065
# Ep 19 | hit            | minD    0.0m | dca_pos 0.950 | vclose_pos 0.996 | los_p95 0.0069
# Ep 20 | hit            | minD    0.1m | dca_pos 0.867 | vclose_pos 0.994 | los_p95 0.0065
#
# --- SUMMARY (20 eps) ---
# Hit Rate:            20/20 (100.0%)
# min_dist mean:       3.5 m
# min_dist p50:        0.0 m
# min_dist p10:        0.0 m
# dca_pos_ratio_mean:  0.920
# vclose_pos_ratio_mean: 0.996
# los_terminal_p95_mean: 0.0073

# %%
import os
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.monitor import Monitor


class HitLogger(BaseCallback):
    def _on_step(self):
        infos = self.locals.get("infos", [])
        for info in infos:
            if "hit" in info:
                if info["hit"]:
                    print("HIT")
                else:
                    print("MISS")

                if self.logger is not None:
                    for key in ("min_dist", "dca_pos_ratio", "vclose_pos_ratio"):
                        if key in info and np.isfinite(info[key]):
                            self.logger.record(
                                f"rollout/{key}",
                                float(info[key]),
                                exclude="stdout",
                            )
        return True


log_dir = "./ppo_missile_tensorboard/"
os.makedirs(log_dir, exist_ok=True)


vec_env = DummyVecEnv([
    lambda: Monitor(
        missile_interception_3d(enemy_mode="static"),
        info_keywords=("min_dist", "dca_pos_ratio", "vclose_pos_ratio")
    )
])


# --------------------------------
# LOAD EXISTING MODEL
# --------------------------------

model = PPO.load(
    "ppo_missile_radius50_17M",
    env=vec_env,
    tensorboard_log=log_dir
)


# --------------------------------
# CONTINUE TRAINING
# --------------------------------

model.learn(
    total_timesteps=2_500_000,
    tb_log_name="ppo_radius25_finetune",
    callback=HitLogger()
)


# --------------------------------
# SAVE NEW MODEL
# --------------------------------

model.save("ppo_missile_radius25_19M")
# Out:
# Logging to ./ppo_missile_tensorboard/ppo_radius25_finetune_1
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 0.947    |
# | time/              |          |
# |    fps             | 597      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 4096     |
# ---------------------------------
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 225          |
# |    ep_rew_mean          | 0.944        |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0035379345 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.7        |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.115       |
# |    n_updates            | 42780        |
# |    policy_gradient_loss | -0.00518     |
# |    std                  | 26.9         |
# |    value_loss           | 0.00171      |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 223         |
# |    ep_rew_mean          | 0.964       |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008898598 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.119      |
# |    n_updates            | 42790       |
# |    policy_gradient_loss | -0.00641    |
# |    std                  | 27          |
# |    value_loss           | 5.89e-05    |
# -----------------------------------------
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | 0.943       |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 4           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004524883 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.11       |
# |    n_updates            | 42800       |
# |    policy_gradient_loss | -0.00665    |
# |    std                  | 26.9        |
# |    value_loss           | 1.53e-05    |
# -----------------------------------------
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 0.931       |
# | time/                   |             |
# |    fps                  | 499         |
# |    iterations           | 5           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004817712 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.114      |
# |    n_updates            | 42810       |
# |    policy_gradient_loss | -0.00687    |
# |    std                  | 26.9        |
# |    value_loss           | 0.00155     |
# -----------------------------------------
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | 0.93        |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 6           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005760741 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.107      |
# |    n_updates            | 42820       |
# |    policy_gradient_loss | -0.00479    |
# |    std                  | 26.7        |
# |    value_loss           | 0.00225     |
# -----------------------------------------
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 247          |
# |    ep_rew_mean          | 0.93         |
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 7            |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0051019946 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.113       |
# |    n_updates            | 42830        |
# |    policy_gradient_loss | -0.005       |
# |    std                  | 27           |
# |    value_loss           | 0.00128      |
# ------------------------------------------
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 248          |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 8            |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0073263273 |
# |    clip_fraction        | 0.0636       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.116       |
# |    n_updates            | 42840        |
# |    policy_gradient_loss | -0.00624     |
# |    std                  | 27.2         |
# |    value_loss           | 0.00119      |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 250        |
# |    ep_rew_mean          | 0.91       |
# | time/                   |            |
# |    fps                  | 519        |
# |    iterations           | 9          |
# |    time_elapsed         | 70         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00477448 |
# |    clip_fraction        | 0.0743     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.8      |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.112     |
# |    n_updates            | 42850      |
# |    policy_gradient_loss | -0.00437   |
# |    std                  | 27         |
# |    value_loss           | 0.00248    |
# ----------------------------------------
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | 0.93        |
# | time/                   |             |
# |    fps                  | 532         |
# |    iterations           | 10          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004577007 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.117      |
# |    n_updates            | 42860       |
# |    policy_gradient_loss | -0.00585    |
# |    std                  | 26.5        |
# |    value_loss           | 0.00286     |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 0.93        |
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 11          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007228547 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.116      |
# |    n_updates            | 42870       |
# |    policy_gradient_loss | -0.0056     |
# |    std                  | 26.6        |
# |    value_loss           | 0.000153    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 0.94        |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 12          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005188939 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.119      |
# |    n_updates            | 42880       |
# |    policy_gradient_loss | -0.00329    |
# |    std                  | 26.8        |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 237          |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 13           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0063697277 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.116       |
# |    n_updates            | 42890        |
# |    policy_gradient_loss | -0.00655     |
# |    std                  | 27.1         |
# |    value_loss           | 4.91e-05     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 14           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0065062633 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.122       |
# |    n_updates            | 42900        |
# |    policy_gradient_loss | -0.00562     |
# |    std                  | 27           |
# |    value_loss           | 2.9e-05      |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 234          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 15           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0072863195 |
# |    clip_fraction        | 0.0626       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.12        |
# |    n_updates            | 42910        |
# |    policy_gradient_loss | -0.00607     |
# |    std                  | 27           |
# |    value_loss           | 2.71e-05     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 16          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003760707 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.111      |
# |    n_updates            | 42920       |
# |    policy_gradient_loss | -0.00495    |
# |    std                  | 27.1        |
# |    value_loss           | 0.000939    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 17          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006305987 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.122      |
# |    n_updates            | 42930       |
# |    policy_gradient_loss | -0.0051     |
# |    std                  | 26.9        |
# |    value_loss           | 3.95e-05    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 18           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0056847073 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.111       |
# |    n_updates            | 42940        |
# |    policy_gradient_loss | -0.00615     |
# |    std                  | 27           |
# |    value_loss           | 0.000829     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 19           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0034980066 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.109       |
# |    n_updates            | 42950        |
# |    policy_gradient_loss | -0.0059      |
# |    std                  | 26.9         |
# |    value_loss           | 0.00108      |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 20          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006584253 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0999     |
# |    n_updates            | 42960       |
# |    policy_gradient_loss | -0.00487    |
# |    std                  | 27.1        |
# |    value_loss           | 0.000106    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 21          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007694316 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.11       |
# |    n_updates            | 42970       |
# |    policy_gradient_loss | -0.00634    |
# |    std                  | 27.2        |
# |    value_loss           | 2.61e-05    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 22           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0059358245 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.112       |
# |    n_updates            | 42980        |
# |    policy_gradient_loss | -0.00584     |
# |    std                  | 27.3         |
# |    value_loss           | 2.2e-05      |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 23           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0058936705 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.11        |
# |    n_updates            | 42990        |
# |    policy_gradient_loss | -0.00729     |
# |    std                  | 27.5         |
# |    value_loss           | 9.38e-06     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 230          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 24           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0051614465 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.124       |
# |    n_updates            | 43000        |
# |    policy_gradient_loss | -0.00589     |
# |    std                  | 27.8         |
# |    value_loss           | 0.000934     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 25          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006765803 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.118      |
# |    n_updates            | 43010       |
# |    policy_gradient_loss | -0.00503    |
# |    std                  | 27.9        |
# |    value_loss           | 0.00126     |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 26           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0058993865 |
# |    clip_fraction        | 0.0813       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.111       |
# |    n_updates            | 43020        |
# |    policy_gradient_loss | -0.00803     |
# |    std                  | 28.2         |
# |    value_loss           | 2.56e-05     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 235          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 27           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0063567837 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.115       |
# |    n_updates            | 43030        |
# |    policy_gradient_loss | -0.00486     |
# |    std                  | 28.1         |
# |    value_loss           | 9.21e-06     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 28          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.006166219 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.116      |
# |    n_updates            | 43040       |
# |    policy_gradient_loss | -0.00871    |
# |    std                  | 28.1        |
# |    value_loss           | 8.5e-06     |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 29          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.005205615 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.114      |
# |    n_updates            | 43050       |
# |    policy_gradient_loss | -0.00736    |
# |    std                  | 28          |
# |    value_loss           | 0.00191     |
# -----------------------------------------
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 238          |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 30           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0049153594 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.114       |
# |    n_updates            | 43060        |
# |    policy_gradient_loss | -0.007       |
# |    std                  | 28.2         |
# |    value_loss           | 7.35e-05     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 238          |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 31           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0050661676 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.124       |
# |    n_updates            | 43070        |
# |    policy_gradient_loss | -0.00577     |
# |    std                  | 28.5         |
# |    value_loss           | 0.00182      |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 244          |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 32           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0051813964 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.126       |
# |    n_updates            | 43080        |
# |    policy_gradient_loss | -0.00712     |
# |    std                  | 28.6         |
# |    value_loss           | 5.33e-05     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.95         |
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 33           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 135168       |
# | train/                  |              |
# |    approx_kl            | 0.0064293807 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.114       |
# |    n_updates            | 43090        |
# |    policy_gradient_loss | -0.00501     |
# |    std                  | 28.8         |
# |    value_loss           | 2.48e-05     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 34          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.005476176 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.108      |
# |    n_updates            | 43100       |
# |    policy_gradient_loss | -0.0051     |
# |    std                  | 28.7        |
# |    value_loss           | 0.000877    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 234          |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 35           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0042601833 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.122       |
# |    n_updates            | 43110        |
# |    policy_gradient_loss | -0.00595     |
# |    std                  | 28.9         |
# |    value_loss           | 4.02e-05     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 36          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.004803962 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.114      |
# |    n_updates            | 43120       |
# |    policy_gradient_loss | -0.00559    |
# |    std                  | 29.3        |
# |    value_loss           | 0.000882    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 37           |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0048003495 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.118       |
# |    n_updates            | 43130        |
# |    policy_gradient_loss | -0.00456     |
# |    std                  | 29.4         |
# |    value_loss           | 1.8e-05      |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 38          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.005193357 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.116      |
# |    n_updates            | 43140       |
# |    policy_gradient_loss | -0.00551    |
# |    std                  | 29.6        |
# |    value_loss           | 1.35e-05    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 39           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0051797936 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.121       |
# |    n_updates            | 43150        |
# |    policy_gradient_loss | -0.00854     |
# |    std                  | 29.3         |
# |    value_loss           | 0.000798     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 40           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0064407545 |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.128       |
# |    n_updates            | 43160        |
# |    policy_gradient_loss | -0.00725     |
# |    std                  | 29.3         |
# |    value_loss           | 3.76e-05     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 231        |
# |    ep_rew_mean          | 0.99       |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 41         |
# |    time_elapsed         | 302        |
# |    total_timesteps      | 167936     |
# | train/                  |            |
# |    approx_kl            | 0.00603989 |
# |    clip_fraction        | 0.064      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11        |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.114     |
# |    n_updates            | 43170      |
# |    policy_gradient_loss | -0.00615   |
# |    std                  | 29.4       |
# |    value_loss           | 1.66e-05   |
# ----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 225          |
# |    ep_rew_mean          | 0.99         |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 42           |
# |    time_elapsed         | 317          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0040084077 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.131       |
# |    n_updates            | 43180        |
# |    policy_gradient_loss | -0.00512     |
# |    std                  | 29.2         |
# |    value_loss           | 1.36e-05     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 223          |
# |    ep_rew_mean          | 0.99         |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 43           |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0053288583 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.12        |
# |    n_updates            | 43190        |
# |    policy_gradient_loss | -0.00636     |
# |    std                  | 29.2         |
# |    value_loss           | 6.2e-06      |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 217          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 545          |
# |    iterations           | 44           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0060601095 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.129       |
# |    n_updates            | 43200        |
# |    policy_gradient_loss | -0.00739     |
# |    std                  | 29.2         |
# |    value_loss           | 3.42e-06     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 222          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 45           |
# |    time_elapsed         | 336          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0060237404 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.118       |
# |    n_updates            | 43210        |
# |    policy_gradient_loss | -0.00522     |
# |    std                  | 29.1         |
# |    value_loss           | 3.07e-06     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 46           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0063768975 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.12        |
# |    n_updates            | 43220        |
# |    policy_gradient_loss | -0.00643     |
# |    std                  | 29.3         |
# |    value_loss           | 1.98e-06     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# MISS
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 0.99         |
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 47           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0055661025 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.115       |
# |    n_updates            | 43230        |
# |    policy_gradient_loss | -0.00457     |
# |    std                  | 29.3         |
# |    value_loss           | 9.48e-06     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 48          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.004400869 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.12       |
# |    n_updates            | 43240       |
# |    policy_gradient_loss | -0.00494    |
# |    std                  | 29.5        |
# |    value_loss           | 0.000668    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# ...
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 817         |
# |    iterations           | 596         |
# |    time_elapsed         | 2984        |
# |    total_timesteps      | 2441216     |
# | train/                  |             |
# |    approx_kl            | 0.004334558 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.131      |
# |    n_updates            | 48720       |
# |    policy_gradient_loss | -0.00616    |
# |    std                  | 37.9        |
# |    value_loss           | 3.02e-07    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 597          |
# |    time_elapsed         | 2988         |
# |    total_timesteps      | 2445312      |
# | train/                  |              |
# |    approx_kl            | 0.0061833523 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.134       |
# |    n_updates            | 48730        |
# |    policy_gradient_loss | -0.00658     |
# |    std                  | 37.9         |
# |    value_loss           | 4.26e-07     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 598          |
# |    time_elapsed         | 2993         |
# |    total_timesteps      | 2449408      |
# | train/                  |              |
# |    approx_kl            | 0.0048001762 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.136       |
# |    n_updates            | 48740        |
# |    policy_gradient_loss | -0.00716     |
# |    std                  | 37.7         |
# |    value_loss           | 3.09e-07     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 599          |
# |    time_elapsed         | 2997         |
# |    total_timesteps      | 2453504      |
# | train/                  |              |
# |    approx_kl            | 0.0050121285 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.3        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.14        |
# |    n_updates            | 48750        |
# |    policy_gradient_loss | -0.00703     |
# |    std                  | 37.5         |
# |    value_loss           | 1.02e-06     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 600          |
# |    time_elapsed         | 3001         |
# |    total_timesteps      | 2457600      |
# | train/                  |              |
# |    approx_kl            | 0.0064013638 |
# |    clip_fraction        | 0.0607       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.3        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.136       |
# |    n_updates            | 48760        |
# |    policy_gradient_loss | -0.00611     |
# |    std                  | 37.8         |
# |    value_loss           | 7.17e-07     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 601         |
# |    time_elapsed         | 3005        |
# |    total_timesteps      | 2461696     |
# | train/                  |             |
# |    approx_kl            | 0.004921737 |
# |    clip_fraction        | 0.0403      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.131      |
# |    n_updates            | 48770       |
# |    policy_gradient_loss | -0.00593    |
# |    std                  | 38.1        |
# |    value_loss           | 3.38e-06    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 602         |
# |    time_elapsed         | 3010        |
# |    total_timesteps      | 2465792     |
# | train/                  |             |
# |    approx_kl            | 0.004059598 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.134      |
# |    n_updates            | 48780       |
# |    policy_gradient_loss | -0.00454    |
# |    std                  | 38.3        |
# |    value_loss           | 4.65e-07    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 603         |
# |    time_elapsed         | 3014        |
# |    total_timesteps      | 2469888     |
# | train/                  |             |
# |    approx_kl            | 0.004360595 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.138      |
# |    n_updates            | 48790       |
# |    policy_gradient_loss | -0.00566    |
# |    std                  | 38          |
# |    value_loss           | 2.54e-07    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 604         |
# |    time_elapsed         | 3018        |
# |    total_timesteps      | 2473984     |
# | train/                  |             |
# |    approx_kl            | 0.004125139 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.134      |
# |    n_updates            | 48800       |
# |    policy_gradient_loss | -0.00541    |
# |    std                  | 38          |
# |    value_loss           | 4.79e-07    |
# -----------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 819          |
# |    iterations           | 605          |
# |    time_elapsed         | 3022         |
# |    total_timesteps      | 2478080      |
# | train/                  |              |
# |    approx_kl            | 0.0048043774 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.132       |
# |    n_updates            | 48810        |
# |    policy_gradient_loss | -0.00521     |
# |    std                  | 38.2         |
# |    value_loss           | 2.14e-07     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 606          |
# |    time_elapsed         | 3026         |
# |    total_timesteps      | 2482176      |
# | train/                  |              |
# |    approx_kl            | 0.0054412195 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.131       |
# |    n_updates            | 48820        |
# |    policy_gradient_loss | -0.00725     |
# |    std                  | 37.9         |
# |    value_loss           | 2.54e-07     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 607          |
# |    time_elapsed         | 3030         |
# |    total_timesteps      | 2486272      |
# | train/                  |              |
# |    approx_kl            | 0.0044027963 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.127       |
# |    n_updates            | 48830        |
# |    policy_gradient_loss | -0.00501     |
# |    std                  | 38.1         |
# |    value_loss           | 3.07e-07     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 608          |
# |    time_elapsed         | 3035         |
# |    total_timesteps      | 2490368      |
# | train/                  |              |
# |    approx_kl            | 0.0038650935 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.137       |
# |    n_updates            | 48840        |
# |    policy_gradient_loss | -0.00547     |
# |    std                  | 38.2         |
# |    value_loss           | 2.59e-07     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 225          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 609          |
# |    time_elapsed         | 3039         |
# |    total_timesteps      | 2494464      |
# | train/                  |              |
# |    approx_kl            | 0.0041517485 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.127       |
# |    n_updates            | 48850        |
# |    policy_gradient_loss | -0.00486     |
# |    std                  | 38.3         |
# |    value_loss           | 8.94e-07     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 610          |
# |    time_elapsed         | 3043         |
# |    total_timesteps      | 2498560      |
# | train/                  |              |
# |    approx_kl            | 0.0041966224 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.135       |
# |    n_updates            | 48860        |
# |    policy_gradient_loss | -0.00703     |
# |    std                  | 38.5         |
# |    value_loss           | 1.14e-06     |
# ------------------------------------------
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# HIT
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 220          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 611          |
# |    time_elapsed         | 3047         |
# |    total_timesteps      | 2502656      |
# | train/                  |              |
# |    approx_kl            | 0.0049455096 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.129       |
# |    n_updates            | 48870        |
# |    policy_gradient_loss | -0.00345     |
# |    std                  | 38.7         |
# |    value_loss           | 2.36e-07     |
# ------------------------------------------

# %%
# ==========================================
# LOAD TRAINED POLICY
# ==========================================

from stable_baselines3 import PPO

model = PPO.load("ppo_missile_radius50_17M")

# deterministic policy (no exploration noise)
policy_fn = lambda obs: model.predict(obs, deterministic=True)[0]


# ==========================================
# RUN EVALUATION
# ==========================================

eval_env = missile_interception_3d(enemy_mode="static")

summary, metrics = evaluate_policy(
    eval_env,
    policy_fn,
    n_episodes=1000,
    seed0=0
)

print("\n===== PPO EVALUATION =====")
for k, v in summary.items():
    print(f"{k}: {v}")
# Out:
# ===== PPO EVALUATION =====
# hit_rate: 1.0
# min_dist_mean: 9.79435405188054
# min_dist_p50: 9.04057502746582
# min_dist_p10: 3.0426722526550294
# time_to_hit_mean: 22.63490000000006
# max_g_mean: 1.000000067949295
# dca_pos_ratio_mean: 0.7563877047531032
# vclose_pos_ratio_mean: 0.9961981889146425
# los_terminal_p95_mean: 2.05750055717032
# violations: {'defense_ground': 0, 'enemy_ground': 0, 'episode_cap': 0, 'debug_cap': 0}
