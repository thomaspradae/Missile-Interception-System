# %%
import gymnasium as gym 
from gymnasium import Env
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import tensorflow as tf
import datetime
import gymnasium as gym
import numpy as np
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
import tensorflow as tf

# # Set seed for reproducibility
# seed = 42
# random.seed(seed)
# np.random.seed(seed)

class missile_interception(Env):
    def __init__(self):
        self.action_space = gym.spaces.discrete.Discrete(3)
        low = np.array([-1, -1, -1, -1, -1, -1, -1, -1, -2, -2, -0.04, -2.828, -70.71, 0, -44.8, 0, -np.inf, -np.inf], dtype=np.float32)
        high = np.array([1, 1, 1, 1, 1, 1, 1, 1, 2, 2, 2.828, 2.828, 70.71, 150, 0, math.pi, np.inf, np.inf], dtype=np.float32)
        self.observation_space = gym.spaces.Box(low=low, high=high, dtype=np.float32)
        self.radius = 0.02

        self.episode_count = 0
        self.distance_t_minus_one = 0
        self.distance_change = 0

        self.out_of_bounds = 0
        self.interceptions = 0
        self.reached_max_steps = 0

        self.defense_positions = []
        self.attack_positions = []

        self.max_steps_per_episode = 150

    def reset(self, seed=None):
        self.defense_positions = []
        self.attack_positions = []
        self.reward = 0
        self.current_step = 0
        self.done = False
        self.create_defense()
        self.create_attack(self.defense)
        self.calc_angle(self.defense, self.attack)
        self.initial_missile_angle()
        self.missile_distance_to_attack()
        # self.graph(self.defense, self.attack)
        self.get_state()

        return self.state, {}

    def create_defense(self):
        x = random.uniform(-0.45, 0.45)
        y = random.uniform(-0.45, 0.45)
        self.defense = np.array([x, y])

    def create_attack(self, defense):
        x_side_left = random.uniform(-0.65, (defense[0] - 0.02) - 0.1)
        x_side_right = random.uniform((defense[0] + 0.02) + 0.1, 0.65)
        y_below = random.uniform((defense[1] - 0.02) - 0.1, -0.65)
        y_above = random.uniform((defense[1] + 0.02) + 0.1, 0.65)
        x_inclusive = random.uniform(-0.65, 0.65)
        y_inclusive = random.uniform(-0.65, 0.65)
        y_below_x_inclusive = np.array([x_inclusive, y_below])
        y_above_x_inclusive = np.array([x_inclusive, y_above])
        x_left_y_inclusive = np.array([x_side_left, y_inclusive])
        x_right_y_inclusive = np.array([x_side_right, y_inclusive])

        self.attack = random.choice([y_below_x_inclusive, y_above_x_inclusive, x_left_y_inclusive, x_right_y_inclusive])

    def calc_angle(self, defense, attack):

        # create an adjacent point of the form (attack_x, defense_y)
        adjacent_point = np.array([attack[0], defense[1]])

        # calculate the distance between the adjacent point and the defense, attack points
        adj_point_defense_len = abs(defense[0] - adjacent_point[0]) 
        adj_point_attack_len = abs(attack[1] - adjacent_point[1])

        # calculate the angle, using soh cah toa, where adj_point_defense_len is the adjacent side and adj_point_attack_len is the opposite side
        self.theta = np.arctan(adj_point_attack_len / adj_point_defense_len)
        
        if attack[0] > defense[0]:
            if attack[1] > defense[1]:
                self.theta = self.theta # 1st quadrant
            else: 
                self.theta = (2*math.pi) - self.theta # 360 - theta
        else:
            if attack[1] > defense[1]:
                self.theta = math.pi - self.theta # 180 - theta
            else:
                self.theta = math.pi + self.theta # 180 + theta
            
        return self.theta
    
    def initial_missile_angle(self):
        self.missile_angle = np.random.uniform(0, 2*math.pi)
        # if self.theta < math.pi:
        #     self.missile_angle = np.random.uniform(0, math.pi)
        # else:
        #     self.missile_angle = np.random.uniform(math.pi, 2*math.pi)

    def calculate_distance(self, point1, point2):
        return math.hypot(point1[0] - point2[0], point1[1] - point2[1])
    
    def missile_distance_to_attack(self):
        self.distance = (self.calculate_distance(self.defense, self.attack) - (2 * self.radius))

    def missile_nav_angle(self, action):
        if action == 0:
            self.missile_angle = self.missile_angle 
        elif action == 1:
            self.missile_angle += 0.174532925
        elif action == 2:
            self.missile_angle -= 0.174532925

    def missle_coord_calc(self):
        self.defense[0] += (0.02 * math.cos(self.missile_angle)) # gotta test this
        self.defense[1] += (0.02 * math.sin(self.missile_angle))

        self.defense_positions.append(self.defense.copy())
        self.attack_positions.append(self.attack.copy())

    def calculate_reward(self):
        self.missile_distance_to_attack()

        if self.distance < 0:
            print("HIT!")
            self.reward = 10000
            self.done = True
            self.interceptions += 1
        else:
            self.distance_change = ((self.distance - self.distance_t_minus_one) / 0.02) 
            if self.distance_change < 0:
                self.reward = -10 * (self.distance_change * (0.03 + 1/self.distance))
            else:
                self.reward = -10 * (self.distance_change * 1 + 1 * (self.distance**2))

            # angle penalty
            self.angle_diff = abs(self.theta - self.missile_angle)
            self.angle_diff = min(self.angle_diff, 2*math.pi - self.angle_diff)
            if self.angle_diff < 0.05:
                try:
                    if 1/self.angle_diff < 100:
                        self.reward += 1/self.angle_diff
                    else:
                        self.reward += 100
                except ZeroDivisionError:
                    self.reward += 100
            else:
                self.reward -= (2 * self.angle_diff)
            
            # time penalty
            self.reward -= 0.05 * self.current_step
                
        if self.defense[0] < -1 or self.defense[0] > 1 or self.defense[1] < -1 or self.defense[1] > 1:
            print("OUT OF BOUNDS")
            self.reward = -1000
            self.done = True
            self.out_of_bounds += 1

    def angle_conversion(self):
        self.sin_theta, self.sin_missile_angle = np.sin(self.theta), np.sin(self.missile_angle)
        self.cos_theta, self.cos_missile_angle = np.cos(self.theta), np.cos(self.missile_angle)

        self.delta_sin = self.sin_theta - self.sin_missile_angle
        self.delta_cos = self.cos_theta - self.cos_missile_angle

    def get_state(self):
        self.angle_conversion()
        reward_component_pos = (self.distance - self.distance_t_minus_one) / 0.02 * (0.03 + 1/self.distance) if ((self.distance - self.distance_t_minus_one) / 0.02) < 0 else 0
        reward_component_neg = (self.distance - self.distance_t_minus_one) / 0.02 * (1 + 1 * (self.distance**2)) if ((self.distance - self.distance_t_minus_one) / 0.02) >= 0 else 0

        self.state = np.array([
            self.attack[0], self.attack[1], self.defense[0], self.defense[1],
            self.sin_theta, self.cos_theta, self.sin_missile_angle, self.cos_missile_angle,
            self.delta_sin, self.delta_cos, self.distance,
            (self.distance - self.distance_t_minus_one),
            ((self.distance - self.distance_t_minus_one) / 0.02),
            self.current_step,
            (-0.05 * self.current_step),
            min(abs(self.theta - self.missile_angle), 2*math.pi - abs(self.theta - self.missile_angle)),
            reward_component_pos,
            reward_component_neg
        ])

    def get_state_dict(self):
        return {"reward": self.reward, "attack_x": self.attack[0], "attack_y": self.attack[1], "defense_x": self.defense[0], "defense_y": self.defense[1], "theta": self.theta, "missile_angle": self.missile_angle, "self.sin_theta": self.sin_theta, "self.cos_theta": self.cos_theta, "self.sin_missile_angle": self.sin_missile_angle, "self.cos_missile_angle": self.cos_missile_angle, "delta_sin": self.delta_sin, "delta_cos": self.delta_cos, "distance": self.distance, "current_step": self.current_step}
                 
    def step(self, action):
        self.distance_t_minus_one = self.distance
        self.missile_nav_angle(action)
        self.missle_coord_calc()
        self.calculate_reward()
        self.current_step += 1

        if self.current_step >= self.max_steps_per_episode:
            print("MAX STEPS REACHED")
            self.done = True
            self.reward = -1000
            self.reached_max_steps += 1

        self.get_state()

        # self.graph(self.defense, self.attack)

        return self.state, self.reward, self.done, False, {}

    def graph(self, defense, attack):
        fig, ax = plt.subplots()
        plt.xlim(-1, 1)
        plt.ylim(-1, 1)

        plt.axhline(0, color='black', linewidth=0.5)
        plt.axvline(0, color='black', linewidth=0.5)
        plt.grid(True)

        # Plot trails
        if self.defense_positions:
            defense_xs, defense_ys = zip(*self.defense_positions)
            ax.plot(defense_xs, defense_ys, 'b-')  # Blue line for defense

        if self.attack_positions:
            attack_xs, attack_ys = zip(*self.attack_positions)
            ax.plot(attack_xs, attack_ys, 'r-')  # Red line for attack

        # Plot current positions
        plt.scatter(defense[0], defense[1], color='black')
        plt.scatter(attack[0], attack[1], color='red')

        ax.set_aspect('equal')
        plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from IPython.display import HTML, display


def animate_episode(episode_data, save_name):
    episode_past_defense_positions = episode_data["past_defense_positions"]
    past_defense_x, past_defense_y = zip(*episode_past_defense_positions)
    episode_attack_positions = episode_data["attack_positions"]
    attack_x, attack_y = zip(*episode_attack_positions)
    episode_defense_positions = episode_data["defense_positions"]
    defense_x, defense_y = zip(*episode_defense_positions)

    # Create figure and axis
    fig, ax = plt.subplots()
    plt.xlim(-1, 1)
    plt.ylim(-1, 1)
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(True)

    trail, = ax.plot([], [], 'b-', label='Defense Trail')  
    scatter1, = ax.plot([], [], 'ro')  # 'ro' means red circles
    scatter2, = ax.plot([], [], 'bo')  # 'ro' means red circles

    # Update function for animation
    def update(frame):
        trail.set_data(past_defense_x[:frame+1], past_defense_y[:frame+1])
        scatter1.set_data(attack_x[frame], attack_y[frame])
        scatter2.set_data(defense_x[frame], defense_y[frame])
        return trail, scatter1, scatter2

    # Create animation
    ani = animation.FuncAnimation(fig, update, frames=len(past_defense_x), interval=200, blit=True)

    # Option 1: Save animation
    ani.save(save_name, writer='pillow')
    print(f"Animation saved as {save_name}")

    # # Option 2: Display using HTML
    # plt.close(fig)
    # video = ani.to_html5_video()
    # html = display(HTML(video))

    plt.show()

# %%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# .........................................................................................................................................................
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# COPY OF THE CODE ABOVE: THIS VERSION IS FOR TESTING THE ANIMATION FUNCTION 

from copy import deepcopy

log_number = 1

def run_episode(env, model):
    # If you have only one environment wrapped, you can directly access it
    single_env = env.envs[0]
    obs = env.reset()
    done = False
    animate = False
    total_reward = 0
    step = 0
    episode_data = None
    global log_number

    print("EPISODE NUMBER:", log_number)

    episode_data = {
    'past_defense_positions': [], # In upgraded code, we'd only need defense_positions, this is slop, let it work for now
    'attack_positions': [],
    'defense_positions': [], # because you're basically storing the same data in two different places
    }

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        episode_data['past_defense_positions'].append(deepcopy(np.array([obs[0][2], obs[0][3]])))
        obs, reward, done, info = env.step(action)
        episode_data['attack_positions'].append(deepcopy(np.array([obs[0][2], obs[0][3]])))
        episode_data['defense_positions'].append(deepcopy(np.array([obs[0][0], obs[0][1]])))
        total_reward += reward
        step += 1

    print("Total Reward:", total_reward)
    log_number += 1
    
    if episode_data is not None:
        episode_file_name = f'episode_{log_number}_v7_dqn_local_mini_tuned.gif'
        animate_episode(episode_data, episode_file_name)
        print(episode_data)

    # Now access the specific attributes from the single_env which is your actual missile_interception instance
    return step, total_reward, single_env.out_of_bounds, single_env.interceptions, single_env.reached_max_steps

# Create the environment
env = make_vec_env(lambda: missile_interception(), n_envs=1)

# Create the model
model = DQN("MlpPolicy", env, verbose=1, tensorboard_log="./dqn_missile_guidance_local_v6")

# Create a summary writer
summary_writer = tf.summary.create_file_writer('./dqn_missile_guidance_local_v6/custom_metrics')

# Training loop
total_timesteps = 2000000
eval_interval = 100000  # Evaluate and log every 10000 steps

for step in range(0, total_timesteps, eval_interval):
    # Train for a number of timesteps
    model.learn(total_timesteps=eval_interval, reset_num_timesteps=False)
    
    # Run an evaluation episode
    episode_length, episode_reward, out_of_bounds, interceptions, reached_max_steps = run_episode(env, model)
    
    # Log the results
    with summary_writer.as_default():
        tf.summary.scalar('Evaluation/Episode Length', episode_length, step=step)
        # Ensure episode_reward and other metrics are scalars by using .item() if they are numpy arrays or tensors
        tf.summary.scalar('Evaluation/Episode Reward', episode_reward.item() if isinstance(episode_reward, np.ndarray) else episode_reward, step=step)
        tf.summary.scalar('Evaluation/Out of Bounds Count', out_of_bounds.item() if isinstance(out_of_bounds, np.ndarray) else out_of_bounds, step=step)
        tf.summary.scalar('Evaluation/Interceptions Count', interceptions.item() if isinstance(interceptions, np.ndarray) else interceptions, step=step)
        tf.summary.scalar('Evaluation/Reached Max Steps Count', reached_max_steps.item() if isinstance(reached_max_steps, np.ndarray) else reached_max_steps, step=step)
        summary_writer.flush()


# Save the final model
model.save("dqn_missile_guidance_v6_local")
# Out:
# Using cpu device
# Logging to ./dqn_missile_guidance_local_v6\DQN_0
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 54.5      |
# |    ep_rew_mean      | -2.05e+03 |
# |    exploration_rate | 0.979     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 2147      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 218       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 19.4      |
# |    n_updates        | 29        |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 65.6      |
# |    ep_rew_mean      | -1.45e+03 |
# |    exploration_rate | 0.95      |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 1858      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 525       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 27.4      |
# |    n_updates        | 106       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 66.1      |
# |    ep_rew_mean      | -1.71e+03 |
# |    exploration_rate | 0.925     |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 1873      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 793       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 94.9      |
# |    n_updates        | 173       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 67.9      |
# |    ep_rew_mean      | -1.64e+03 |
# |    exploration_rate | 0.897     |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 1735      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1087      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 54.4      |
# |    n_updates        | 246       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 64.7      |
# |    ep_rew_mean      | -1.65e+03 |
# |    exploration_rate | 0.877     |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 1685      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1294      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 15.7      |
# |    n_updates        | 298       |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 72.6      |
# |    ep_rew_mean      | -1.48e+03 |
# |    exploration_rate | 0.834     |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 1636      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 1743      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 26.1      |
# |    n_updates        | 410       |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 79.2      |
# |    ep_rew_mean      | -1.58e+03 |
# |    exploration_rate | 0.789     |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 1651      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2218      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 41.3      |
# |    n_updates        | 529       |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 80.8      |
# |    ep_rew_mean      | -1.56e+03 |
# |    exploration_rate | 0.754     |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 1661      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2587      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 14.5      |
# |    n_updates        | 621       |
# -----------------------------------
# OUT OF BOUNDS
# HIT!
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 80.4      |
# |    ep_rew_mean      | -1.18e+03 |
# |    exploration_rate | 0.725     |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 1645      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2895      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 14.1      |
# |    n_updates        | 698       |
# -----------------------------------
# HIT!
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.7     |
# |    ep_rew_mean      | -872     |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1639     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3388     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 22.3     |
# |    n_updates        | 821      |
# ----------------------------------
# HIT!
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | -670     |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1622     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3859     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13.7     |
# |    n_updates        | 939      |
# ----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -810     |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1638     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4347     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 43.8     |
# |    n_updates        | 1061     |
# ----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -955     |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1643     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4805     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 14.5     |
# |    n_updates        | 1176     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 93.6      |
# |    ep_rew_mean      | -1.03e+03 |
# |    exploration_rate | 0.502     |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 1645      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 5242      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 12.8      |
# |    n_updates        | 1285      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 94        |
# |    ep_rew_mean      | -1.14e+03 |
# |    exploration_rate | 0.464     |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 1644      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 5640      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 10.5      |
# |    n_updates        | 1384      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 94.1      |
# |    ep_rew_mean      | -1.21e+03 |
# |    exploration_rate | 0.428     |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 1647      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 6021      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.6       |
# |    n_updates        | 1480      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 96.2      |
# |    ep_rew_mean      | -1.28e+03 |
# |    exploration_rate | 0.379     |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 1636      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 6541      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 46.5      |
# |    n_updates        | 1610      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 94.8      |
# |    ep_rew_mean      | -1.31e+03 |
# |    exploration_rate | 0.352     |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 1632      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 6822      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 9.84      |
# |    n_updates        | 1680      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 92.9      |
# |    ep_rew_mean      | -1.35e+03 |
# |    exploration_rate | 0.329     |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 1630      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 7063      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36.4      |
# |    n_updates        | 1740      |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 92        |
# |    ep_rew_mean      | -1.32e+03 |
# |    exploration_rate | 0.301     |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 1626      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 7357      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 65.1      |
# |    n_updates        | 1814      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 93.5      |
# |    ep_rew_mean      | -1.39e+03 |
# |    exploration_rate | 0.254     |
# | time/               |           |
# |    episodes         | 84        |
# |    fps              | 1605      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 7853      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.81      |
# |    n_updates        | 1938      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -1.4e+03 |
# |    exploration_rate | 0.233    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1602     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8069     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 325      |
# |    n_updates        | 1992     |
# ----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 91.4      |
# |    ep_rew_mean      | -1.44e+03 |
# |    exploration_rate | 0.201     |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 1602      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 8406      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.6       |
# |    n_updates        | 2076      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 90.3      |
# |    ep_rew_mean      | -1.46e+03 |
# |    exploration_rate | 0.176     |
# | time/               |           |
# |    episodes         | 96        |
# |    fps              | 1601      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 8673      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.06      |
# |    n_updates        | 2143      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 89.5      |
# |    ep_rew_mean      | -1.47e+03 |
# |    exploration_rate | 0.15      |
# | time/               |           |
# |    episodes         | 100       |
# |    fps              | 1596      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 8948      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.99      |
# |    n_updates        | 2211      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 89.3      |
# |    ep_rew_mean      | -1.44e+03 |
# |    exploration_rate | 0.131     |
# | time/               |           |
# |    episodes         | 104       |
# |    fps              | 1593      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 9151      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 38        |
# |    n_updates        | 2262      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 88.9      |
# |    ep_rew_mean      | -1.47e+03 |
# |    exploration_rate | 0.106     |
# | time/               |           |
# |    episodes         | 108       |
# |    fps              | 1587      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 9411      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.11      |
# |    n_updates        | 2327      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 88        |
# |    ep_rew_mean      | -1.44e+03 |
# |    exploration_rate | 0.0887    |
# | time/               |           |
# |    episodes         | 112       |
# |    fps              | 1584      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 9593      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 39.9      |
# |    n_updates        | 2373      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 88.5      |
# |    ep_rew_mean      | -1.46e+03 |
# |    exploration_rate | 0.0555    |
# | time/               |           |
# |    episodes         | 116       |
# |    fps              | 1579      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 9942      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 43.9      |
# |    n_updates        | 2460      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# HIT!
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 89.3      |
# |    ep_rew_mean      | -1.26e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 120       |
# |    fps              | 1574      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 10225     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 10.2      |
# |    n_updates        | 2531      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -1.3e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1570     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 10570    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.6     |
# |    n_updates        | 2617     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 85.9      |
# |    ep_rew_mean      | -1.28e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 128       |
# |    fps              | 1566      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 10811     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 8.42      |
# |    n_updates        | 2677      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 84.9      |
# |    ep_rew_mean      | -1.28e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 132       |
# |    fps              | 1563      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 11080     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 37.7      |
# |    n_updates        | 2744      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 84.4      |
# |    ep_rew_mean      | -1.43e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 136       |
# |    fps              | 1559      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 11333     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6         |
# |    n_updates        | 2808      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 82.4      |
# |    ep_rew_mean      | -1.57e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 140       |
# |    fps              | 1557      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 11630     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 20.6      |
# |    n_updates        | 2882      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 80.5      |
# |    ep_rew_mean      | -1.68e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 144       |
# |    fps              | 1554      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 11912     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 38.8      |
# |    n_updates        | 2952      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 79        |
# |    ep_rew_mean      | -1.62e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 148       |
# |    fps              | 1552      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 12242     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 8.07      |
# |    n_updates        | 3035      |
# -----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 78.4      |
# |    ep_rew_mean      | -1.57e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 152       |
# |    fps              | 1552      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 12647     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 10.1      |
# |    n_updates        | 3136      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# HIT!
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 77.5      |
# |    ep_rew_mean      | -1.41e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 156       |
# |    fps              | 1538      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 12995     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.85      |
# |    n_updates        | 3223      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 79.4      |
# |    ep_rew_mean      | -1.33e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 160       |
# |    fps              | 1537      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 13584     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.48      |
# |    n_updates        | 3370      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 81.6      |
# |    ep_rew_mean      | -1.27e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 164       |
# |    fps              | 1534      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 14184     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.71      |
# |    n_updates        | 3520      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 82.4      |
# |    ep_rew_mean      | -1.19e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 168       |
# |    fps              | 1525      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 14784     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.72      |
# |    n_updates        | 3670      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 85.6      |
# |    ep_rew_mean      | -1.14e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 172       |
# |    fps              | 1515      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 15384     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.16      |
# |    n_updates        | 3820      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 89.2      |
# |    ep_rew_mean      | -1.07e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 176       |
# |    fps              | 1514      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 15984     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 11.8      |
# |    n_updates        | 3970      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 92.3      |
# |    ep_rew_mean      | -1.08e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 180       |
# |    fps              | 1512      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 16584     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.95      |
# |    n_updates        | 4120      |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -974     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1511     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 17184    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.86     |
# |    n_updates        | 4270     |
# ----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | -943     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1512     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 17784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.94     |
# |    n_updates        | 4420     |
# ----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -933     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1509     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 18384    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.6     |
# |    n_updates        | 4570     |
# ----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -891     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1510     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 18984    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.91     |
# |    n_updates        | 4720     |
# ----------------------------------
# MAX STEPS REACHED
# HIT!
# HIT!
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -545     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1509     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 19315    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.88     |
# |    n_updates        | 4803     |
# ----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -531     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1509     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 19915    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.13     |
# |    n_updates        | 4953     |
# ----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | -461     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1508     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 20515    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 23.8     |
# |    n_updates        | 5103     |
# ----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -478     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1508     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 21009    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 41.1     |
# |    n_updates        | 5227     |
# ----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -455     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1508     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 21491    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12       |
# |    n_updates        | 5347     |
# ----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -690     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1504     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 21814    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.05     |
# |    n_updates        | 5428     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -747     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1503     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 22204    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.94     |
# |    n_updates        | 5525     |
# ----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -764     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1502     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 22590    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 32.8     |
# |    n_updates        | 5622     |
# ----------------------------------
# OUT OF BOUNDS
# HIT!
# MAX STEPS REACHED
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -651     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1496     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 22858    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.53     |
# |    n_updates        | 5689     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -671     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1495     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 23145    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 43.7     |
# |    n_updates        | 5761     |
# ----------------------------------
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -666     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1495     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 23490    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.08     |
# |    n_updates        | 5847     |
# ----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -695     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1493     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 23827    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 43.3     |
# |    n_updates        | 5931     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -749     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1490     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24091    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.3     |
# |    n_updates        | 5997     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -766     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1488     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24306    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 42.9     |
# |    n_updates        | 6051     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -914     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1486     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24502    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.13     |
# |    n_updates        | 6100     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -962     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1487     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24769    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 76.1     |
# |    n_updates        | 6167     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 108       |
# |    ep_rew_mean      | -1.01e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 264       |
# |    fps              | 1486      |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 25030     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.59      |
# |    n_updates        | 6232      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 105       |
# |    ep_rew_mean      | -1.05e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 268       |
# |    fps              | 1486      |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 25250     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 39.7      |
# |    n_updates        | 6287      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -1.1e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1485     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 25498    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.98     |
# |    n_updates        | 6349     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 97.3      |
# |    ep_rew_mean      | -1.14e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 276       |
# |    fps              | 1485      |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 25715     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.2       |
# |    n_updates        | 6403      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 93.7      |
# |    ep_rew_mean      | -1.16e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 280       |
# |    fps              | 1484      |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 25951     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 45.2      |
# |    n_updates        | 6462      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 90.9      |
# |    ep_rew_mean      | -1.16e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 284       |
# |    fps              | 1484      |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 26278     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 10.1      |
# |    n_updates        | 6544      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 87.7      |
# |    ep_rew_mean      | -1.18e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 288       |
# |    fps              | 1483      |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 26554     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.41      |
# |    n_updates        | 6613      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 84.2      |
# |    ep_rew_mean      | -1.17e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 292       |
# |    fps              | 1483      |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 26807     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 9.12      |
# |    n_updates        | 6676      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 81.5      |
# |    ep_rew_mean      | -1.22e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 296       |
# |    fps              | 1483      |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 27132     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.37      |
# |    n_updates        | 6757      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 80.8      |
# |    ep_rew_mean      | -1.57e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 300       |
# |    fps              | 1478      |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 27394     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.9       |
# |    n_updates        | 6823      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.9     |
# |    ep_rew_mean      | -1.6e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1478     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 27705    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 29.4     |
# |    n_updates        | 6901     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.2     |
# |    ep_rew_mean      | -1.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1478     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 28137    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.93     |
# |    n_updates        | 7009     |
# ----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 74.1      |
# |    ep_rew_mean      | -1.68e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 312       |
# |    fps              | 1478      |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 28421     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 39.9      |
# |    n_updates        | 7080      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 72.1      |
# |    ep_rew_mean      | -1.68e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 316       |
# |    fps              | 1478      |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 28703     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 35.2      |
# |    n_updates        | 7150      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# HIT!
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 70.8      |
# |    ep_rew_mean      | -1.49e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 320       |
# |    fps              | 1478      |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 28897     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.99      |
# |    n_updates        | 7199      |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 70.3      |
# |    ep_rew_mean      | -1.44e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 324       |
# |    fps              | 1477      |
# |    time_elapsed     | 19        |
# ...
# | time/               |           |
# |    episodes         | 6088      |
# |    fps              | 1463      |
# |    time_elapsed     | 58        |
# |    total_timesteps  | 785728    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 212       |
# |    n_updates        | 196406    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 141       |
# |    ep_rew_mean      | -1.14e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6092      |
# |    fps              | 1464      |
# |    time_elapsed     | 58        |
# |    total_timesteps  | 786328    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 177       |
# |    n_updates        | 196556    |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -1.18e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6096      |
# |    fps              | 1464      |
# |    time_elapsed     | 59        |
# |    total_timesteps  | 786899    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 279       |
# |    n_updates        | 196699    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -1.23e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6100      |
# |    fps              | 1465      |
# |    time_elapsed     | 59        |
# |    total_timesteps  | 787468    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 128       |
# |    n_updates        | 196841    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -1.23e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6104      |
# |    fps              | 1465      |
# |    time_elapsed     | 60        |
# |    total_timesteps  | 788030    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 138       |
# |    n_updates        | 196982    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 141       |
# |    ep_rew_mean      | -1.22e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6108      |
# |    fps              | 1463      |
# |    time_elapsed     | 60        |
# |    total_timesteps  | 788622    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 261       |
# |    n_updates        | 197130    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -1.21e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6112      |
# |    fps              | 1460      |
# |    time_elapsed     | 61        |
# |    total_timesteps  | 789222    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 89.8      |
# |    n_updates        | 197280    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -1.25e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6116      |
# |    fps              | 1458      |
# |    time_elapsed     | 61        |
# |    total_timesteps  | 789791    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 265       |
# |    n_updates        | 197422    |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# OUT OF BOUNDS
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 141       |
# |    ep_rew_mean      | -1.22e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6120      |
# |    fps              | 1453      |
# |    time_elapsed     | 62        |
# |    total_timesteps  | 790325    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 195       |
# |    n_updates        | 197556    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 141       |
# |    ep_rew_mean      | -1.21e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6124      |
# |    fps              | 1450      |
# |    time_elapsed     | 62        |
# |    total_timesteps  | 790925    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 331       |
# |    n_updates        | 197706    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 143       |
# |    ep_rew_mean      | -1.25e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6128      |
# |    fps              | 1451      |
# |    time_elapsed     | 63        |
# |    total_timesteps  | 791525    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 176       |
# |    n_updates        | 197856    |
# -----------------------------------
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 143       |
# |    ep_rew_mean      | -1.25e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6132      |
# |    fps              | 1447      |
# |    time_elapsed     | 63        |
# |    total_timesteps  | 792119    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 348       |
# |    n_updates        | 198004    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 143       |
# |    ep_rew_mean      | -1.24e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6136      |
# |    fps              | 1446      |
# |    time_elapsed     | 64        |
# |    total_timesteps  | 792719    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 409       |
# |    n_updates        | 198154    |
# -----------------------------------
# OUT OF BOUNDS
# OUT OF BOUNDS
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -1.25e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6140      |
# |    fps              | 1447      |
# |    time_elapsed     | 64        |
# |    total_timesteps  | 793273    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 150       |
# |    n_updates        | 198293    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -1.28e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6144      |
# |    fps              | 1446      |
# |    time_elapsed     | 64        |
# |    total_timesteps  | 793873    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 291       |
# |    n_updates        | 198443    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# OUT OF BOUNDS
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -1.27e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6148      |
# |    fps              | 1446      |
# |    time_elapsed     | 65        |
# |    total_timesteps  | 794443    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 164       |
# |    n_updates        | 198585    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 143       |
# |    ep_rew_mean      | -1.22e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6152      |
# |    fps              | 1446      |
# |    time_elapsed     | 65        |
# |    total_timesteps  | 795043    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 153       |
# |    n_updates        | 198735    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# HIT!
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -1.07e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6156      |
# |    fps              | 1446      |
# |    time_elapsed     | 66        |
# |    total_timesteps  | 795501    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 119       |
# |    n_updates        | 198850    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# MAX STEPS REACHED
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 144       |
# |    ep_rew_mean      | -1.18e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 6160      |
# |    fps              | 1443      |
# |    time_elapsed     | 66        |
# |    total_timesteps  | 796101    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 138       |
# |    n_updates        | 199000    |
# -----------------------------------
# MAX STEPS REACHED
# MAX STEPS REACHED
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 64
#      60 eval_interval = 100000  # Evaluate and log every 10000 steps
#      62 for step in range(0, total_timesteps, eval_interval):
#      63     # Train for a number of timesteps
# ---> 64     model.learn(total_timesteps=eval_interval, reset_num_timesteps=False)
#      66     # Run an evaluation episode
#      67     episode_length, episode_reward, out_of_bounds, interceptions, reached_max_steps = run_episode(env, model)
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\dqn\dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\dqn\dqn.py:193, in DQN.train(self, gradient_steps, batch_size)
#     190 losses = []
#     191 for _ in range(gradient_steps):
#     192     # Sample replay buffer
# --> 193     replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)  # type: ignore[union-attr]
#     195     with th.no_grad():
#     196         # Compute the next Q-values using the target network
#     197         next_q_values = self.q_net_target(replay_data.next_observations)
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\buffers.py:297, in ReplayBuffer.sample(self, batch_size, env)
#     285 """
#     286 Sample elements from the replay buffer.
#     287 Custom sampling when using memory efficient variant,
#    (...)
#     294 :return:
#     295 """
#     296 if not self.optimize_memory_usage:
# --> 297     return super().sample(batch_size=batch_size, env=env)
#     298 # Do not sample the element with index `self.pos` as the transitions is invalid
#     299 # (we use only one array to store `obs` and `next_obs`)
#     300 if self.full:
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\buffers.py:114, in BaseBuffer.sample(self, batch_size, env)
#     112 upper_bound = self.buffer_size if self.full else self.pos
#     113 batch_inds = np.random.randint(0, upper_bound, size=batch_size)
# --> 114 return self._get_samples(batch_inds, env=env)
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\buffers.py:313, in ReplayBuffer._get_samples(self, batch_inds, env)
#     311     next_obs = self._normalize_obs(self.observations[(batch_inds + 1) % self.buffer_size, env_indices, :], env)
#     312 else:
# --> 313     next_obs = self._normalize_obs(self.next_observations[batch_inds, env_indices, :], env)
#     315 data = (
#     316     self._normalize_obs(self.observations[batch_inds, env_indices, :], env),
#     317     self.actions[batch_inds, env_indices, :],
#    (...)
#     322     self._normalize_reward(self.rewards[batch_inds, env_indices].reshape(-1, 1), env),
#     323 )
#     324 return ReplayBufferSamples(*tuple(map(self.to_torch, data)))
#
# File c:\Users\thoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\buffers.py:141, in BaseBuffer._normalize_obs(obs, env)
#     138         return th.tensor(array, device=self.device)
#     139     return th.as_tensor(array, device=self.device)
# --> 141 @staticmethod
#     142 def _normalize_obs(
#     143     obs: Union[np.ndarray, Dict[str, np.ndarray]],
#     144     env: Optional[VecNormalize] = None,
#     145 ) -> Union[np.ndarray, Dict[str, np.ndarray]]:
#     146     if env is not None:
#     147         return env.normalize_obs(obs)
#
# KeyboardInterrupt:
