# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
from matplotlib.animation import FuncAnimation
import time
import math

# Set a mudafuggin seed
random.seed(0)

class Point: 
    def __init__(self, type):
        self.type = type
        self.coordinates = np.array([0, 0])
        self.radius = 0.2

    def create_target(self):
        x = random.uniform(-3.0, 3.0)
        y = random.uniform(-2.0, 2.0)
        self.coordinates = np.array([x, y])
        self.theta = 0
        return self.coordinates, self.theta
    
    def create_defense(self, target):
        x = random.uniform((target.coordinates[0] - self.radius) - 1.5, (target.coordinates[0] + self.radius) + 1.5)
        y = random.uniform((target.coordinates[1] - self.radius) - 1.5, (target.coordinates[1] + self.radius) + 1.5)
        self.coordinates = np.array([x, y])
        return self.coordinates
    
    def create_attack(self, target):
        x_side_left = random.uniform(-9.5, (target.coordinates[0] - self.radius) - 2)
        x_side_right = random.uniform((target.coordinates[0] + self.radius) + 2, 9.5)
        y_below = random.uniform((target.coordinates[1] - self.radius) - 2, -9.5)
        y_above = random.uniform((target.coordinates[1] + self.radius) + 2, 9.5)
        x_inclusive = random.uniform(-9.5, 9.5)
        y_inclusive = random.uniform(-9.5, 9.5)
        y_below_x_inclusive = np.array([x_inclusive, y_below])
        y_above_x_inclusive = np.array([x_inclusive, y_above])
        x_left_y_inclusive = np.array([x_side_left, y_inclusive])
        x_right_y_inclusive = np.array([x_side_right, y_inclusive])

        self.coordinates = random.choice([y_below_x_inclusive, y_above_x_inclusive, x_left_y_inclusive, x_right_y_inclusive])
        
        # Create attack_theta
        self.AT_abs_length = math.hypot(self.coordinates[0] - target.coordinates[0], self.coordinates[1] - target.coordinates[1])
        self.length_adjacent_r = abs(target.coordinates[0] - self.coordinates[0])
        self.attack_theta_rad = math.acos(self.length_adjacent_r / self.AT_abs_length)

        if self.coordinates[0] < target.coordinates[0]:
            if self.coordinates[1] < target.coordinates[1]:
                self.attack_theta_rad = self.attack_theta_rad
            else:
                self.attack_theta_rad = ((2 * math.pi) - self.attack_theta_rad)
            
        else:
            if self.coordinates[1] < target.coordinates[1]:
                self.attack_theta_rad = ((math.pi) - self.attack_theta_rad)
            else:
                self.attack_theta_rad = ((math.pi) + self.attack_theta_rad)

        return self.coordinates, self.attack_theta_rad

class Missile:
    def __init__(self, type):
        self.type = type
        self.coordinates = np.array([0, 0])
        self.radius = 0.2
    
    def create_attack_missile(self, attack):
        self.speed = 1
        self.theta = attack.attack_theta_rad
        self.coordinates = attack.coordinates
        self.fired = False
        return self.coordinates, self.theta, self.speed, self.fired
    
    def fire_attack_missile(self, global_time):
        self.fired = True
        self.fired_time = global_time
        return self.fired, self.fired_time
    
    def fire_defense_missile(self, global_time):
        self.fired = True
        self.fired_time = global_time
        self.initial_position = np.array([self.coordinates[0], self.coordinates[1]])
        return self.fired, self.fired_time
    
    def create_defense_missile(self, defense, global_time, theta):
        self.speed = 1
        self.theta = theta
        self.coordinates = defense.coordinates
        self.fired = False
        self.fired_time = 0 
        self.missile_clock = global_time - self.fired_time
        self.defense_missile_to_attack_missile = None
        self.start_distance = None
        self.reward_diff = None

class Environment:
    def __init__(self):
        self.global_time = 0

        self.target = None
        self.defense = None
        self.attack = None
        self.attack_missile = None
        self.defense_missiles = []

        self.attack_missile_to_target = None

    def set_episode(self, global_time):
        self.reward = 0
        self.target = Point('target')
        self.defense = Point('defense')
        self.attack = Point('attack')

        self.target.create_target()
        self.defense.create_defense(self.target)
        self.attack.create_attack(self.target)

        self.attack_missile = Missile('attack')
        self.attack_missile.create_attack_missile(self.attack)
        self.attack_missile.fire_attack_missile(global_time)
        self.attack_missile_to_target = self.distance_attack_to_target(self.attack_missile)

        self.defense_missiles = []

    def calculate_distance(self, point1, point2):
        return math.hypot(point1[0] - point2[0], point1[1] - point2[1])
    
    def distance_attack_to_target(self, attack_missile):
        # print("//////////////////////////////////////////")
        # print("Attack Missile PRINTING:", attack_missile)
        # print("Attack Missile Coordinates:", attack_missile.coordinates)
        # print("Static Attack Coordinates:", self.attack.coordinates)
        # print("self.target.coordinates:", self.target.coordinates)
        # print("self.attack.coordinates:", attack_missile.coordinates)
        # print("self.calculate_distance(attack_missile.coordinates, self.target.coordinates):", self.calculate_distance(attack_missile.coordinates, self.target.coordinates))
        # print("Global Time:", self.global_time)
        # print("------------------------------------------")
        self.attack_missile_to_target = (self.calculate_distance(attack_missile.coordinates, self.target.coordinates) - (attack_missile.radius + self.target.radius))
        # print("Attack Missile PRINTING:", attack_missile)
        # print("Attack Missile Coordinates:", attack_missile.coordinates)
        # print("Static Attack Coordinates:", self.attack.coordinates)
        # print("self.target.coordinates:", self.target.coordinates)
        # print("self.attack.coordinates:", attack_missile.coordinates)
        # print("self.calculate_distance(attack_missile.coordinates, self.target.coordinates):", self.calculate_distance(attack_missile.coordinates, self.target.coordinates))
        # print("Global Time:", self.global_time)
        return self.attack_missile_to_target
    
    def indv_distance_defense_to_attack(self, missile, attack_missile):
        missile.defense_missile_to_attack_missile = (self.calculate_distance(missile.coordinates, attack_missile.coordinates) - (missile.radius + attack_missile.radius))
        return missile.defense_missile_to_attack_missile

    def distance_defense_to_attack(self, attack_missile):
        for missile in self.defense_missiles:
            # print("\n############################################")
            # print("Defense Coordinates:", missile.coordinates)
            # print("Attack Coordinates:", attack_missile.coordinates)
            missile.defense_missile_to_attack_missile = (self.calculate_distance(missile.coordinates, attack_missile.coordinates) - (missile.radius + attack_missile.radius))
            # print("Defense Missile to Attack Missile:", missile.defense_missile_to_attack_missile)
            # print("self.calculate_distance(missile.coordinates, attack_missile.coordinates):", self.calculate_distance(missile.coordinates, attack_missile.coordinates))
            # print("Defense Coordinates:", missile.coordinates)
            # print("Attack Coordinates:", attack_missile.coordinates)
            # print("############################################\n")

    def local_create_defense_missile(self, defense, global_time, defense_missiles, theta):
        defense_missile = Missile('defense')
        defense_missile.create_defense_missile(defense, global_time, theta)
        defense_missiles.append(defense_missile)
        return defense_missile 

    def update_attack_missile_position(self, attack_missile):
        new_coordx = self.attack.coordinates[0] + self.attack_missile.speed * self.global_time * math.cos(self.attack_missile.theta)
        new_coordy = self.attack.coordinates[1] + self.attack_missile.speed * self.global_time * math.sin(self.attack_missile.theta)
        print("\n++++++++++++++++++++++++++++++++++++++++")
        print("Attack Missile PRINTING:", attack_missile)
        print("Attack Missile Coordinates:", attack_missile.coordinates)
        print("Attack Missile Theta:", attack_missile.theta)
        print("Attack Missile Speed:", attack_missile.speed)
        print("Attack Missile Fired Time:", attack_missile.fired_time)
        print("Attack Missile to Target:", self.attack_missile_to_target)
        print("--")
        print("Original Attack Stationary Coordinates:", self.attack.coordinates)
        print("Global Time:", self.global_time)
        print("Distance to target:", self.attack_missile_to_target)
        print("New coord baby:", new_coordx, new_coordy)
        print("Missile x:", new_coordx)
        print("Missile y:", new_coordy)
        print("Missile coords old:", self.attack_missile.coordinates)
        print("----------------------------------------")
        attack_missile.coordinates = np.array([new_coordx, new_coordy])
        self.attack_missile.coordinates = np.array([new_coordx, new_coordy])
        print("Original Attack Stationary Coordinates:", self.attack.coordinates)
        print("Chaning Coords", attack_missile.coordinates)
        print("Global Time:", self.global_time)
        print("Missile coords new:", self.attack_missile.coordinates)
        print("Missile coords x", self.attack_missile.coordinates[0])
        print("Missile coords y", self.attack_missile.coordinates[1])
        print("Distance to target:", self.attack_missile_to_target)
        print("++++++++++++++++++++++++++++++++++++++++\n")
        # self.attack_missile.coordinates[0] = self.attack.coordinates[0] + self.attack_missile.speed * self.global_time * math.cos(self.attack_missile.theta)
        # self.attack_missile.coordinates[1] = self.attack.coordinates[1] + self.attack_missile.speed * self.global_time * math.sin(self.attack_missile.theta)
    
    def update_defense_missile_positions(self):
        for missile in self.defense_missiles:
            new_coordx = missile.initial_position[0] + missile.speed * (self.global_time - missile.fired_time) * math.cos(missile.theta)
            new_coordy = missile.initial_position[1] + missile.speed * (self.global_time - missile.fired_time) * math.sin(missile.theta)
            print("New coord baby:", new_coordx, new_coordy)
            print("Missile x:", new_coordx)
            print("Missile y:", new_coordy)
            missile.coordinates = np.array([new_coordx, new_coordy])
            print("Missile coords new:", missile.coordinates)

    def distance_reward(self, reward):
        print("\n********************************")
        print("DEBUGGING DISTANE REWARD AS PART OF REWARD")
        print("Missiles: ", self.defense_missiles)
        for missile in self.defense_missiles:
            print("Missile Coordinates:", missile.coordinates)
            print("Missile.start_distance:", missile.start_distance)
            print("Missile.defense_missile_to_attack_missile:", missile.defense_missile_to_attack_missile)
            print("missile.start_distance - missile.defense_missile_to_attack_missile:", missile.start_distance - missile.defense_missile_to_attack_missile)
            missile.reward_diff = missile.start_distance - missile.defense_missile_to_attack_missile
            print("Missile.reward_diff:", missile.reward_diff)
            print("Reward:", reward)
            reward += missile.reward_diff
            print("Reward after missile.reward_diff:", reward)
        print("********************************\n")
            
        return reward

    def check_impact(self):
        for missile in self.defense_missiles:
            if missile.defense_missile_to_attack_missile < 0:
                return 100, True
        
        if env.attack_missile_to_target < 0:
            return -100, True

        return 0, False

    def update_defense_missiles(self):
        if len(self.defense_missiles) > 0:
            self.update_defense_missile_positions()
            self.distance_defense_to_attack()

    def update_world(self):
        self.update_attack_missile_position()
        self.distance_attack_to_target()
        self.update_defense_missiles()

    def step(self, action):
        create_missile, fire_now = action
        create_missile_condition, theta = create_missile

        self.update_attack_missile_position(self.attack_missile)
        self.distance_attack_to_target(self.attack_missile)

        if create_missile_condition:
            self.local_create_defense_missile(self.defense, self.global_time, self.defense_missiles, theta)

        if fire_now:
            self.defense_missiles[-1].fire_defense_missile(self.global_time)
            self.defense_missiles[-1].start_distance = self.indv_distance_defense_to_attack(self.defense_missiles[-1], self.attack_missile)
            
        if len(self.defense_missiles) > 0:
            self.update_defense_missile_positions()
            self.distance_defense_to_attack(self.attack_missile)

        print("\n............................................")
        print("DEBUGGING REWARD")
        print("Global Time:", self.global_time)
        print("Reward before:", self.reward)
        print("--------------\n")
        distance_reward = self.distance_reward(self.reward)
        print("Distance Reward:", distance_reward)
        print("Self.reward after .distance_reward():", self.reward)
        print("Self.reward after self.reward += distance_reward:", self.reward)
        impact_reward, done = self.check_impact()
        self.reward += impact_reward
        print("Reward after:", self.reward)
        print("............................................\n")

        self.global_time += 0.1

        return self.reward, done
    
    def debugging_get_state(self, steps):
        print("\n--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-")
        print("Environment created.")
        print("-------------------------------------------------------------------")
        print("ENVIRONMENT CONSTANTS")
        print("global_time:", self.global_time)
        print("Target coordinates:", self.target.coordinates)
        print("Defense coordinates:", self.defense.coordinates)
        print("Attack coordinates:", self.attack.coordinates)
        print("Reward:", self.reward)
        print("-------------------------------------------------------------------")
        print("ATTACK MISSILE")
        print("Attack Missile Fired:", self.attack_missile.fired)
        print("Attack Missile Coordinates:", self.attack_missile.coordinates)
        print("Attack Missile Theta:", self.attack_missile.theta)
        print("Attack Missile Speed:", self.attack_missile.speed)
        print("Attack Missile Fired Time:", self.attack_missile.fired_time)
        print("Attack Missile to Target:", self.attack_missile_to_target)
        print("-------------------------------------------------------------------")
        print("DEFENSE MISSILES")
        if len(self.defense_missiles) > 0:
            i = 0
            for missile in self.defense_missiles:
                print("Defense Missile", i)
        else:
            print("No defense missiles created.")

        step_num = 1
        for step in steps:
            print("\n--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-")
            print("Step", step_num)
            print("BEFORE STEP: Environment recieved to make step")
            print("global_time:", self.global_time)
            print("Attack Missile Coordinates:", self.attack_missile.coordinates)
            print("Reward:", self.reward)
            print("-------------------------------------------------------------------")
            print("STEP")
            self.step(step)
            print(f"Step = Create a missile: {step[0][0]}, theta: {step[0][1]}, fire_now: {step[1]}")
            print("-------------------------------------------------------------------")
            print("AFTER STEP: Environment after step")
            print("global_time:", self.global_time)
            print("Attack Missile Coordinates:", self.attack_missile.coordinates)
            print("Reward:", self.reward)
            print("-------------------------------------------------------------------")
            print("DEFENSE MISSILES")
            print("Defense Missiles Count:", len(self.defense_missiles))
            print("Defense Missiles:", self.defense_missiles)

            i = 0
            for missile in self.defense_missiles:
                i += 1
                print("\n~~~~~~~~~~~~~~~~~")
                print("Defense Missile", i)
                print("Defense Missile Corrdinates:", missile.coordinates)
                print("Defense Missile Theta:", missile.theta)
                print("Defense Missile Fired:", missile.fired)
                print("Defense Missile Fired Time:", missile.fired_time)
                print("Defense Missile Missile Clock:", missile.missile_clock)
                print("Global Time:", self.global_time)
                print("Fired Time:", missile.fired_time)
                print("Global Time - Fired Time:", self.global_time - missile.fired_time)
                print("Defense Missile to Attack Missile:", missile.defense_missile_to_attack_missile)
                print("Defense Missile Start Distance:", missile.start_distance)
                print("Reward Difference:", missile.reward_diff)
                print("~~~~~~~~~~~~~~~~~\n")

            print("-------------------------------------------------------------------")
            print("IMPACT CHECK & SUMMARY")
            print("Attack Coordinates:", self.attack.coordinates)
            print("Target Coordinates:", self.target.coordinates)
            print("Defense Coordinates:", self.defense.coordinates)
            print("Attack Missile to Target:", self.attack_missile_to_target)
            print("Reward:", self.reward)
            print("Impact Check:", self.check_impact())
            print("--")
            print("Attack Missile Coordinates:", self.attack_missile.coordinates)
            print("Attack distance to target:", self.attack_missile_to_target)
            print("--")
            for missile in self.defense_missiles:
                print("Defense Missile Coordinates:", missile.coordinates)
                print("Defense Missile to Attack Missile:", missile.defense_missile_to_attack_missile)
                print("Reward Difference:", missile.reward_diff)
                print("--")

            print("--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-\n")
            step_num += 1

# (0.2) Create the environment. -------------------------------------------------------
env = Environment()
env.set_episode(env.global_time)

# (0.3) Create the steps. --------------------------------------------------------------
steps = [((True, 1.867502), True), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False), ((False, None), False)]
# (0.4) Debugging the environment. -----------------------------------------------------
env.debugging_get_state(steps)
# Out:
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Environment created.
# -------------------------------------------------------------------
# ENVIRONMENT CONSTANTS
# global_time: 0
# Target coordinates: [2.06653111 1.03181761]
# Defense coordinates: [1.79647448 0.21213456]
# Attack coordinates: [-0.44465787  5.1330371 ]
# Reward: 0
# -------------------------------------------------------------------
# ATTACK MISSILE
# Attack Missile Fired: True
# Attack Missile Coordinates: [-0.44465787  5.1330371 ]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 4.4089574110349
# -------------------------------------------------------------------
# DEFENSE MISSILES
# No defense missiles created.
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 1
# BEFORE STEP: Environment recieved to make step
# global_time: 0
# Attack Missile Coordinates: [-0.44465787  5.1330371 ]
# Reward: 0
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.44465787  5.1330371 ]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 4.4089574110349
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0
# Distance to target: 4.4089574110349
# New coord baby: -0.4446578711052389 5.133037099497839
# Missile x: -0.4446578711052389
# Missile y: 5.133037099497839
# Missile coords old: [-0.44465787  5.1330371 ]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [-0.44465787  5.1330371 ]
# Global Time: 0
# Missile coords new: [-0.44465787  5.1330371 ]
# Missile coords x -0.4446578711052389
# Missile coords y 5.133037099497839
# Distance to target: 4.4089574110349
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.7964744839751614 0.21213456275728537
# Missile x: 1.7964744839751614
# Missile y: 0.21213456275728537
# Missile coords new: [1.79647448 0.21213456]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0
# Reward before: 0
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.79647448 0.21213456]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 5.007213331198228
# missile.start_distance - missile.defense_missile_to_attack_missile: 0.0
# Missile.reward_diff: 0.0
# Reward: 0
# Reward after missile.reward_diff: 0.0
# ********************************
#
# Distance Reward: 0.0
# Self.reward after .distance_reward(): 0
# Self.reward after self.reward += distance_reward: 0.0
# Reward after: 0.0
# ............................................
#
# Step = Create a missile: True, theta: 1.867502, fire_now: True
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.1
# Attack Missile Coordinates: [-0.44465787  5.1330371 ]
# Reward: 0.0
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.79647448 0.21213456]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.1
# Fired Time: 0
# Global Time - Fired Time: 0.1
# Defense Missile to Attack Missile: 5.007213331198228
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 0.0
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 4.4089574110349
# Reward: 0.0
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [-0.44465787  5.1330371 ]
# Attack distance to target: 4.4089574110349
# --
# Defense Missile Coordinates: [1.79647448 0.21213456]
# Defense Missile to Attack Missile: 5.007213331198228
# Reward Difference: 0.0
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 2
# BEFORE STEP: Environment recieved to make step
# global_time: 0.1
# Attack Missile Coordinates: [-0.44465787  5.1330371 ]
# Reward: 0.0
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.44465787  5.1330371 ]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 4.4089574110349
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.1
# Distance to target: 4.4089574110349
# New coord baby: -0.3924388812989825 5.0477541756290245
# Missile x: -0.3924388812989825
# Missile y: 5.0477541756290245
# Missile coords old: [-0.44465787  5.1330371 ]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [-0.39243888  5.04775418]
# Global Time: 0.1
# Missile coords new: [-0.39243888  5.04775418]
# Missile coords x -0.3924388812989825
# Missile coords y 5.0477541756290245
# Distance to target: 4.4089574110349
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.7672373421570244 0.307765047114033
# Missile x: 1.7672373421570244
# Missile y: 0.307765047114033
# Missile coords new: [1.76723734 0.30776505]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.1
# Reward before: 0.0
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.76723734 0.30776505]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 4.808809684429016
# missile.start_distance - missile.defense_missile_to_attack_missile: 0.1984036467692123
# Missile.reward_diff: 0.1984036467692123
# Reward: 0.0
# Reward after missile.reward_diff: 0.1984036467692123
# ********************************
#
# Distance Reward: 0.1984036467692123
# Self.reward after .distance_reward(): 0.0
# Self.reward after self.reward += distance_reward: 0.1984036467692123
# Reward after: 0.1984036467692123
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.2
# Attack Missile Coordinates: [-0.39243888  5.04775418]
# Reward: 0.1984036467692123
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.76723734 0.30776505]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.2
# Fired Time: 0
# Global Time - Fired Time: 0.2
# Defense Missile to Attack Missile: 4.808809684429016
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 0.1984036467692123
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 4.308957411034901
# Reward: 0.1984036467692123
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [-0.39243888  5.04775418]
# Attack distance to target: 4.308957411034901
# --
# Defense Missile Coordinates: [1.76723734 0.30776505]
# Defense Missile to Attack Missile: 4.808809684429016
# Reward Difference: 0.1984036467692123
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 3
# BEFORE STEP: Environment recieved to make step
# global_time: 0.2
# Attack Missile Coordinates: [-0.39243888  5.04775418]
# Reward: 0.1984036467692123
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.39243888  5.04775418]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 4.308957411034901
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.2
# Distance to target: 4.308957411034901
# New coord baby: -0.34021989149272613 4.962471251760209
# Missile x: -0.34021989149272613
# Missile y: 4.962471251760209
# Missile coords old: [-0.39243888  5.04775418]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [-0.34021989  4.96247125]
# Global Time: 0.2
# Missile coords new: [-0.34021989  4.96247125]
# Missile coords x -0.34021989149272613
# Missile coords y 4.962471251760209
# Distance to target: 4.308957411034901
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.7380002003388877 0.40339553147078067
# Missile x: 1.7380002003388877
# Missile y: 0.40339553147078067
# Missile coords new: [1.7380002  0.40339553]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.2
# Reward before: 0.1984036467692123
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.7380002  0.40339553]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 4.610406188466676
# missile.start_distance - missile.defense_missile_to_attack_missile: 0.3968071427315518
# Missile.reward_diff: 0.3968071427315518
# Reward: 0.1984036467692123
# Reward after missile.reward_diff: 0.5952107895007641
# ********************************
#
# Distance Reward: 0.5952107895007641
# Self.reward after .distance_reward(): 0.1984036467692123
# Self.reward after self.reward += distance_reward: 0.7936144362699764
# Reward after: 0.7936144362699764
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.30000000000000004
# Attack Missile Coordinates: [-0.34021989  4.96247125]
# Reward: 0.7936144362699764
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.7380002  0.40339553]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.30000000000000004
# Fired Time: 0
# Global Time - Fired Time: 0.30000000000000004
# Defense Missile to Attack Missile: 4.610406188466676
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 0.3968071427315518
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 4.2089574110349
# Reward: 0.7936144362699764
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [-0.34021989  4.96247125]
# Attack distance to target: 4.2089574110349
# --
# Defense Missile Coordinates: [1.7380002  0.40339553]
# Defense Missile to Attack Missile: 4.610406188466676
# Reward Difference: 0.3968071427315518
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 4
# BEFORE STEP: Environment recieved to make step
# global_time: 0.30000000000000004
# Attack Missile Coordinates: [-0.34021989  4.96247125]
# Reward: 0.7936144362699764
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.34021989  4.96247125]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 4.2089574110349
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.30000000000000004
# Distance to target: 4.2089574110349
# New coord baby: -0.2880009016864697 4.877188327891394
# Missile x: -0.2880009016864697
# Missile y: 4.877188327891394
# Missile coords old: [-0.34021989  4.96247125]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [-0.2880009   4.87718833]
# Global Time: 0.30000000000000004
# Missile coords new: [-0.2880009   4.87718833]
# Missile coords x -0.2880009016864697
# Missile coords y 4.877188327891394
# Distance to target: 4.2089574110349
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.7087630585207507 0.4990260158275283
# Missile x: 1.7087630585207507
# Missile y: 0.4990260158275283
# Missile coords new: [1.70876306 0.49902602]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.30000000000000004
# Reward before: 0.7936144362699764
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.70876306 0.49902602]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 4.412002861964947
# missile.start_distance - missile.defense_missile_to_attack_missile: 0.5952104692332814
# Missile.reward_diff: 0.5952104692332814
# Reward: 0.7936144362699764
# Reward after missile.reward_diff: 1.3888249055032578
# ********************************
#
# Distance Reward: 1.3888249055032578
# Self.reward after .distance_reward(): 0.7936144362699764
# Self.reward after self.reward += distance_reward: 2.182439341773234
# Reward after: 2.182439341773234
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.4
# Attack Missile Coordinates: [-0.2880009   4.87718833]
# Reward: 2.182439341773234
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.70876306 0.49902602]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.4
# Fired Time: 0
# Global Time - Fired Time: 0.4
# Defense Missile to Attack Missile: 4.412002861964947
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 0.5952104692332814
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 4.1089574110349005
# Reward: 2.182439341773234
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [-0.2880009   4.87718833]
# Attack distance to target: 4.1089574110349005
# --
# Defense Missile Coordinates: [1.70876306 0.49902602]
# Defense Missile to Attack Missile: 4.412002861964947
# Reward Difference: 0.5952104692332814
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 5
# BEFORE STEP: Environment recieved to make step
# global_time: 0.4
# Attack Missile Coordinates: [-0.2880009   4.87718833]
# Reward: 2.182439341773234
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.2880009   4.87718833]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 4.1089574110349005
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.4
# Distance to target: 4.1089574110349005
# New coord baby: -0.2357819118802133 4.791905404022579
# Missile x: -0.2357819118802133
# Missile y: 4.791905404022579
# Missile coords old: [-0.2880009   4.87718833]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [-0.23578191  4.7919054 ]
# Global Time: 0.4
# Missile coords new: [-0.23578191  4.7919054 ]
# Missile coords x -0.2357819118802133
# Missile coords y 4.791905404022579
# Distance to target: 4.1089574110349005
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.679525916702614 0.5946565001842758
# Missile x: 1.679525916702614
# Missile y: 0.5946565001842758
# Missile coords new: [1.67952592 0.5946565 ]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.4
# Reward before: 2.182439341773234
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.67952592 0.5946565 ]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 4.213599726786287
# missile.start_distance - missile.defense_missile_to_attack_missile: 0.7936136044119415
# Missile.reward_diff: 0.7936136044119415
# Reward: 2.182439341773234
# Reward after missile.reward_diff: 2.9760529461851757
# ********************************
#
# Distance Reward: 2.9760529461851757
# Self.reward after .distance_reward(): 2.182439341773234
# Self.reward after self.reward += distance_reward: 5.15849228795841
# Reward after: 5.15849228795841
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.5
# Attack Missile Coordinates: [-0.23578191  4.7919054 ]
# Reward: 5.15849228795841
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.67952592 0.5946565 ]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.5
# Fired Time: 0
# Global Time - Fired Time: 0.5
# Defense Missile to Attack Missile: 4.213599726786287
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 0.7936136044119415
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 4.0089574110349
# Reward: 5.15849228795841
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [-0.23578191  4.7919054 ]
# Attack distance to target: 4.0089574110349
# --
# Defense Missile Coordinates: [1.67952592 0.5946565 ]
# Defense Missile to Attack Missile: 4.213599726786287
# Reward Difference: 0.7936136044119415
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 6
# BEFORE STEP: Environment recieved to make step
# global_time: 0.5
# Attack Missile Coordinates: [-0.23578191  4.7919054 ]
# Reward: 5.15849228795841
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.23578191  4.7919054 ]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 4.0089574110349
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.5
# Distance to target: 4.0089574110349
# New coord baby: -0.1835629220739569 4.706622480153764
# Missile x: -0.1835629220739569
# Missile y: 4.706622480153764
# Missile coords old: [-0.23578191  4.7919054 ]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [-0.18356292  4.70662248]
# Global Time: 0.5
# Missile coords new: [-0.18356292  4.70662248]
# Missile coords x -0.1835629220739569
# Missile coords y 4.706622480153764
# Distance to target: 4.0089574110349
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.650288774884477 0.6902869845410236
# Missile x: 1.650288774884477
# Missile y: 0.6902869845410236
# Missile coords new: [1.65028877 0.69028698]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.5
# Reward before: 5.15849228795841
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.65028877 0.69028698]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 4.015196808722819
# missile.start_distance - missile.defense_missile_to_attack_missile: 0.9920165224754092
# Missile.reward_diff: 0.9920165224754092
# Reward: 5.15849228795841
# Reward after missile.reward_diff: 6.150508810433819
# ********************************
#
# Distance Reward: 6.150508810433819
# Self.reward after .distance_reward(): 5.15849228795841
# Self.reward after self.reward += distance_reward: 11.30900109839223
# Reward after: 11.30900109839223
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.6
# Attack Missile Coordinates: [-0.18356292  4.70662248]
# Reward: 11.30900109839223
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.65028877 0.69028698]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.6
# Fired Time: 0
# Global Time - Fired Time: 0.6
# Defense Missile to Attack Missile: 4.015196808722819
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 0.9920165224754092
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 3.908957411034901
# Reward: 11.30900109839223
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [-0.18356292  4.70662248]
# Attack distance to target: 3.908957411034901
# --
# Defense Missile Coordinates: [1.65028877 0.69028698]
# Defense Missile to Attack Missile: 4.015196808722819
# Reward Difference: 0.9920165224754092
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 7
# BEFORE STEP: Environment recieved to make step
# global_time: 0.6
# Attack Missile Coordinates: [-0.18356292  4.70662248]
# Reward: 11.30900109839223
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.18356292  4.70662248]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 3.908957411034901
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.6
# Distance to target: 3.908957411034901
# New coord baby: -0.13134393226770052 4.6213395562849495
# Missile x: -0.13134393226770052
# Missile y: 4.6213395562849495
# Missile coords old: [-0.18356292  4.70662248]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [-0.13134393  4.62133956]
# Global Time: 0.6
# Missile coords new: [-0.13134393  4.62133956]
# Missile coords x -0.13134393226770052
# Missile coords y 4.6213395562849495
# Distance to target: 3.908957411034901
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.6210516330663403 0.7859174688977711
# Missile x: 1.6210516330663403
# Missile y: 0.7859174688977711
# Missile coords new: [1.62105163 0.78591747]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.6
# Reward before: 11.30900109839223
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.62105163 0.78591747]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 3.816794138420778
# missile.start_distance - missile.defense_missile_to_attack_missile: 1.19041919277745
# Missile.reward_diff: 1.19041919277745
# Reward: 11.30900109839223
# Reward after missile.reward_diff: 12.49942029116968
# ********************************
#
# Distance Reward: 12.49942029116968
# Self.reward after .distance_reward(): 11.30900109839223
# Self.reward after self.reward += distance_reward: 23.808421389561907
# Reward after: 23.808421389561907
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.7
# Attack Missile Coordinates: [-0.13134393  4.62133956]
# Reward: 23.808421389561907
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.62105163 0.78591747]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.7
# Fired Time: 0
# Global Time - Fired Time: 0.7
# Defense Missile to Attack Missile: 3.816794138420778
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 1.19041919277745
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 3.808957411034901
# Reward: 23.808421389561907
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [-0.13134393  4.62133956]
# Attack distance to target: 3.808957411034901
# --
# Defense Missile Coordinates: [1.62105163 0.78591747]
# Defense Missile to Attack Missile: 3.816794138420778
# Reward Difference: 1.19041919277745
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 8
# BEFORE STEP: Environment recieved to make step
# global_time: 0.7
# Attack Missile Coordinates: [-0.13134393  4.62133956]
# Reward: 23.808421389561907
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.13134393  4.62133956]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 3.808957411034901
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.7
# Distance to target: 3.808957411034901
# New coord baby: -0.07912494246144414 4.536056632416134
# Missile x: -0.07912494246144414
# Missile y: 4.536056632416134
# Missile coords old: [-0.13134393  4.62133956]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [-0.07912494  4.53605663]
# Global Time: 0.7
# Missile coords new: [-0.07912494  4.53605663]
# Missile coords x -0.07912494246144414
# Missile coords y 4.536056632416134
# Distance to target: 3.808957411034901
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.5918144912482033 0.8815479532545187
# Missile x: 1.5918144912482033
# Missile y: 0.8815479532545187
# Missile coords new: [1.59181449 0.88154795]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.7
# Reward before: 23.808421389561907
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.59181449 0.88154795]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 3.618391752578822
# missile.start_distance - missile.defense_missile_to_attack_missile: 1.3888215786194062
# Missile.reward_diff: 1.3888215786194062
# Reward: 23.808421389561907
# Reward after missile.reward_diff: 25.197242968181314
# ********************************
#
# Distance Reward: 25.197242968181314
# Self.reward after .distance_reward(): 23.808421389561907
# Self.reward after self.reward += distance_reward: 49.00566435774322
# Reward after: 49.00566435774322
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.7999999999999999
# Attack Missile Coordinates: [-0.07912494  4.53605663]
# Reward: 49.00566435774322
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.59181449 0.88154795]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.7999999999999999
# Fired Time: 0
# Global Time - Fired Time: 0.7999999999999999
# Defense Missile to Attack Missile: 3.618391752578822
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 1.3888215786194062
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 3.7089574110349006
# Reward: 49.00566435774322
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [-0.07912494  4.53605663]
# Attack distance to target: 3.7089574110349006
# --
# Defense Missile Coordinates: [1.59181449 0.88154795]
# Defense Missile to Attack Missile: 3.618391752578822
# Reward Difference: 1.3888215786194062
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 9
# BEFORE STEP: Environment recieved to make step
# global_time: 0.7999999999999999
# Attack Missile Coordinates: [-0.07912494  4.53605663]
# Reward: 49.00566435774322
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.07912494  4.53605663]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 3.7089574110349006
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.7999999999999999
# Distance to target: 3.7089574110349006
# New coord baby: -0.026905952655187748 4.450773708547319
# Missile x: -0.026905952655187748
# Missile y: 4.450773708547319
# Missile coords old: [-0.07912494  4.53605663]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [-0.02690595  4.45077371]
# Global Time: 0.7999999999999999
# Missile coords new: [-0.02690595  4.45077371]
# Missile coords x -0.026905952655187748
# Missile coords y 4.450773708547319
# Distance to target: 3.7089574110349006
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.5625773494300663 0.9771784376112663
# Missile x: 1.5625773494300663
# Missile y: 0.9771784376112663
# Missile coords new: [1.56257735 0.97717844]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.7999999999999999
# Reward before: 49.00566435774322
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.56257735 0.97717844]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 3.419989695519761
# missile.start_distance - missile.defense_missile_to_attack_missile: 1.587223635678467
# Missile.reward_diff: 1.587223635678467
# Reward: 49.00566435774322
# Reward after missile.reward_diff: 50.59288799342169
# ********************************
#
# Distance Reward: 50.59288799342169
# Self.reward after .distance_reward(): 49.00566435774322
# Self.reward after self.reward += distance_reward: 99.59855235116491
# Reward after: 99.59855235116491
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.8999999999999999
# Attack Missile Coordinates: [-0.02690595  4.45077371]
# Reward: 99.59855235116491
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.56257735 0.97717844]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.8999999999999999
# Fired Time: 0
# Global Time - Fired Time: 0.8999999999999999
# Defense Missile to Attack Missile: 3.419989695519761
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 1.587223635678467
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 3.608957411034901
# Reward: 99.59855235116491
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [-0.02690595  4.45077371]
# Attack distance to target: 3.608957411034901
# --
# Defense Missile Coordinates: [1.56257735 0.97717844]
# Defense Missile to Attack Missile: 3.419989695519761
# Reward Difference: 1.587223635678467
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 10
# BEFORE STEP: Environment recieved to make step
# global_time: 0.8999999999999999
# Attack Missile Coordinates: [-0.02690595  4.45077371]
# Reward: 99.59855235116491
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [-0.02690595  4.45077371]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 3.608957411034901
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.8999999999999999
# Distance to target: 3.608957411034901
# New coord baby: 0.02531303715106864 4.365490784678505
# Missile x: 0.02531303715106864
# Missile y: 4.365490784678505
# Missile coords old: [-0.02690595  4.45077371]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [0.02531304 4.36549078]
# Global Time: 0.8999999999999999
# Missile coords new: [0.02531304 4.36549078]
# Missile coords x 0.02531303715106864
# Missile coords y 4.365490784678505
# Distance to target: 3.608957411034901
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.5333402076119296 1.072808921968014
# Missile x: 1.5333402076119296
# Missile y: 1.072808921968014
# Missile coords new: [1.53334021 1.07280892]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.8999999999999999
# Reward before: 99.59855235116491
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.53334021 1.07280892]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 3.2215880212788996
# missile.start_distance - missile.defense_missile_to_attack_missile: 1.7856253099193284
# Missile.reward_diff: 1.7856253099193284
# Reward: 99.59855235116491
# Reward after missile.reward_diff: 101.38417766108424
# ********************************
#
# Distance Reward: 101.38417766108424
# Self.reward after .distance_reward(): 99.59855235116491
# Self.reward after self.reward += distance_reward: 200.98273001224914
# Reward after: 200.98273001224914
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 0.9999999999999999
# Attack Missile Coordinates: [0.02531304 4.36549078]
# Reward: 200.98273001224914
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.53334021 1.07280892]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 0.9999999999999999
# Fired Time: 0
# Global Time - Fired Time: 0.9999999999999999
# Defense Missile to Attack Missile: 3.2215880212788996
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 1.7856253099193284
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 3.508957411034901
# Reward: 200.98273001224914
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [0.02531304 4.36549078]
# Attack distance to target: 3.508957411034901
# --
# Defense Missile Coordinates: [1.53334021 1.07280892]
# Defense Missile to Attack Missile: 3.2215880212788996
# Reward Difference: 1.7856253099193284
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 11
# BEFORE STEP: Environment recieved to make step
# global_time: 0.9999999999999999
# Attack Missile Coordinates: [0.02531304 4.36549078]
# Reward: 200.98273001224914
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [0.02531304 4.36549078]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 3.508957411034901
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 0.9999999999999999
# Distance to target: 3.508957411034901
# New coord baby: 0.07753202695732497 4.280207860809689
# Missile x: 0.07753202695732497
# Missile y: 4.280207860809689
# Missile coords old: [0.02531304 4.36549078]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [0.07753203 4.28020786]
# Global Time: 0.9999999999999999
# Missile coords new: [0.07753203 4.28020786]
# Missile coords x 0.07753202695732497
# Missile coords y 4.280207860809689
# Distance to target: 3.508957411034901
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.5041030657937928 1.1684394063247616
# Missile x: 1.5041030657937928
# Missile y: 1.1684394063247616
# Missile coords new: [1.50410307 1.16843941]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 0.9999999999999999
# Reward before: 200.98273001224914
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.50410307 1.16843941]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 3.0231867964185763
# missile.start_distance - missile.defense_missile_to_attack_missile: 1.9840265347796517
# Missile.reward_diff: 1.9840265347796517
# Reward: 200.98273001224914
# Reward after missile.reward_diff: 202.96675654702878
# ********************************
#
# Distance Reward: 202.96675654702878
# Self.reward after .distance_reward(): 200.98273001224914
# Self.reward after self.reward += distance_reward: 403.94948655927794
# Reward after: 403.94948655927794
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 1.0999999999999999
# Attack Missile Coordinates: [0.07753203 4.28020786]
# Reward: 403.94948655927794
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.50410307 1.16843941]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 1.0999999999999999
# Fired Time: 0
# Global Time - Fired Time: 1.0999999999999999
# Defense Missile to Attack Missile: 3.0231867964185763
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 1.9840265347796517
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 3.4089574110349004
# Reward: 403.94948655927794
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [0.07753203 4.28020786]
# Attack distance to target: 3.4089574110349004
# --
# Defense Missile Coordinates: [1.50410307 1.16843941]
# Defense Missile to Attack Missile: 3.0231867964185763
# Reward Difference: 1.9840265347796517
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 12
# BEFORE STEP: Environment recieved to make step
# global_time: 1.0999999999999999
# Attack Missile Coordinates: [0.07753203 4.28020786]
# Reward: 403.94948655927794
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [0.07753203 4.28020786]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 3.4089574110349004
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 1.0999999999999999
# Distance to target: 3.4089574110349004
# New coord baby: 0.12975101676358136 4.1949249369408745
# Missile x: 0.12975101676358136
# Missile y: 4.1949249369408745
# Missile coords old: [0.07753203 4.28020786]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [0.12975102 4.19492494]
# Global Time: 1.0999999999999999
# Missile coords new: [0.12975102 4.19492494]
# Missile coords x 0.12975101676358136
# Missile coords y 4.1949249369408745
# Distance to target: 3.4089574110349004
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.4748659239756559 1.264069890681509
# Missile x: 1.4748659239756559
# Missile y: 1.264069890681509
# Missile coords new: [1.47486592 1.26406989]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 1.0999999999999999
# Reward before: 403.94948655927794
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.47486592 1.26406989]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 2.824786103881641
# missile.start_distance - missile.defense_missile_to_attack_missile: 2.182427227316587
# Missile.reward_diff: 2.182427227316587
# Reward: 403.94948655927794
# Reward after missile.reward_diff: 406.1319137865945
# ********************************
#
# Distance Reward: 406.1319137865945
# Self.reward after .distance_reward(): 403.94948655927794
# Self.reward after self.reward += distance_reward: 810.0814003458725
# Reward after: 810.0814003458725
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 1.2
# Attack Missile Coordinates: [0.12975102 4.19492494]
# Reward: 810.0814003458725
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.47486592 1.26406989]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 1.2
# Fired Time: 0
# Global Time - Fired Time: 1.2
# Defense Missile to Attack Missile: 2.824786103881641
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 2.182427227316587
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 3.3089574110349007
# Reward: 810.0814003458725
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [0.12975102 4.19492494]
# Attack distance to target: 3.3089574110349007
# --
# Defense Missile Coordinates: [1.47486592 1.26406989]
# Defense Missile to Attack Missile: 2.824786103881641
# Reward Difference: 2.182427227316587
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 13
# BEFORE STEP: Environment recieved to make step
# global_time: 1.2
# Attack Missile Coordinates: [0.12975102 4.19492494]
# Reward: 810.0814003458725
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [0.12975102 4.19492494]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 3.3089574110349007
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 1.2
# Distance to target: 3.3089574110349007
# New coord baby: 0.18197000656983786 4.10964201307206
# Missile x: 0.18197000656983786
# Missile y: 4.10964201307206
# Missile coords old: [0.12975102 4.19492494]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [0.18197001 4.10964201]
# Global Time: 1.2
# Missile coords new: [0.18197001 4.10964201]
# Missile coords x 0.18197000656983786
# Missile coords y 4.10964201307206
# Distance to target: 3.3089574110349007
# ++++++++++++++++++++++++++++++++++++++++
#
# ...
# Reward: 1664324.1998205418
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [0.7041599  3.25681277]
# Attack distance to target: 2.2089574110348997
# --
# Defense Missile Coordinates: [1.15325736 2.31600522]
# Defense Missile to Attack Missile: 0.6425005443635575
# Reward Difference: 4.36471278683467
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 24
# BEFORE STEP: Environment recieved to make step
# global_time: 2.3000000000000007
# Attack Missile Coordinates: [0.7041599  3.25681277]
# Reward: 1664324.1998205418
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [0.7041599  3.25681277]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 2.2089574110348997
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 2.3000000000000007
# Distance to target: 2.2089574110348997
# New coord baby: 0.7563788944386587 3.1715298505150944
# Missile x: 0.7563788944386587
# Missile y: 3.1715298505150944
# Missile coords old: [0.7041599  3.25681277]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [0.75637889 3.17152985]
# Global Time: 2.3000000000000007
# Missile coords new: [0.75637889 3.17152985]
# Missile coords x 0.7563788944386587
# Missile coords y 3.1715298505150944
# Distance to target: 2.2089574110348997
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.1240202221580131 2.4116357029624815
# Missile x: 1.1240202221580131
# Missile y: 2.4116357029624815
# Missile coords new: [1.12402022 2.4116357 ]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 2.3000000000000007
# Reward before: 1664324.1998205418
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.12402022 2.4116357 ]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 0.44415594609761644
# missile.start_distance - missile.defense_missile_to_attack_missile: 4.5630573851006115
# Missile.reward_diff: 4.5630573851006115
# Reward: 1664324.1998205418
# Reward after missile.reward_diff: 1664328.762877927
# ********************************
#
# Distance Reward: 1664328.762877927
# Self.reward after .distance_reward(): 1664324.1998205418
# Self.reward after self.reward += distance_reward: 3328652.962698469
# Reward after: 3328652.962698469
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 2.400000000000001
# Attack Missile Coordinates: [0.75637889 3.17152985]
# Reward: 3328652.962698469
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.12402022 2.4116357 ]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 2.400000000000001
# Fired Time: 0
# Global Time - Fired Time: 2.400000000000001
# Defense Missile to Attack Missile: 0.44415594609761644
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 4.5630573851006115
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 2.1089574110349
# Reward: 3328652.962698469
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [0.75637889 3.17152985]
# Attack distance to target: 2.1089574110349
# --
# Defense Missile Coordinates: [1.12402022 2.4116357 ]
# Defense Missile to Attack Missile: 0.44415594609761644
# Reward Difference: 4.5630573851006115
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 25
# BEFORE STEP: Environment recieved to make step
# global_time: 2.400000000000001
# Attack Missile Coordinates: [0.75637889 3.17152985]
# Reward: 3328652.962698469
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [0.75637889 3.17152985]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 2.1089574110349
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 2.400000000000001
# Distance to target: 2.1089574110349
# New coord baby: 0.8085978842449151 3.086246926646279
# Missile x: 0.8085978842449151
# Missile y: 3.086246926646279
# Missile coords old: [0.75637889 3.17152985]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [0.80859788 3.08624693]
# Global Time: 2.400000000000001
# Missile coords new: [0.80859788 3.08624693]
# Missile coords x 0.8085978842449151
# Missile coords y 3.086246926646279
# Distance to target: 2.1089574110349
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.0947830803398761 2.5072661873192295
# Missile x: 1.0947830803398761
# Missile y: 2.5072661873192295
# Missile coords new: [1.09478308 2.50726619]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 2.400000000000001
# Reward before: 3328652.962698469
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.09478308 2.50726619]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 0.24584879265630588
# missile.start_distance - missile.defense_missile_to_attack_missile: 4.7613645385419225
# Missile.reward_diff: 4.7613645385419225
# Reward: 3328652.962698469
# Reward after missile.reward_diff: 3328657.7240630076
# ********************************
#
# Distance Reward: 3328657.7240630076
# Self.reward after .distance_reward(): 3328652.962698469
# Self.reward after self.reward += distance_reward: 6657310.686761476
# Reward after: 6657310.686761476
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 2.500000000000001
# Attack Missile Coordinates: [0.80859788 3.08624693]
# Reward: 6657310.686761476
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.09478308 2.50726619]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 2.500000000000001
# Fired Time: 0
# Global Time - Fired Time: 2.500000000000001
# Defense Missile to Attack Missile: 0.24584879265630588
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 4.7613645385419225
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 2.0089574110348996
# Reward: 6657310.686761476
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [0.80859788 3.08624693]
# Attack distance to target: 2.0089574110348996
# --
# Defense Missile Coordinates: [1.09478308 2.50726619]
# Defense Missile to Attack Missile: 0.24584879265630588
# Reward Difference: 4.7613645385419225
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 26
# BEFORE STEP: Environment recieved to make step
# global_time: 2.500000000000001
# Attack Missile Coordinates: [0.80859788 3.08624693]
# Reward: 6657310.686761476
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [0.80859788 3.08624693]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 2.0089574110348996
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 2.500000000000001
# Distance to target: 2.0089574110348996
# New coord baby: 0.8608168740511715 3.0009640027774642
# Missile x: 0.8608168740511715
# Missile y: 3.0009640027774642
# Missile coords old: [0.80859788 3.08624693]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [0.86081687 3.000964  ]
# Global Time: 2.500000000000001
# Missile coords new: [0.86081687 3.000964  ]
# Missile coords x 0.8608168740511715
# Missile coords y 3.0009640027774642
# Distance to target: 2.0089574110348996
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.0655459385217392 2.602896671675977
# Missile x: 1.0655459385217392
# Missile y: 2.602896671675977
# Missile coords new: [1.06554594 2.60289667]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 2.500000000000001
# Reward before: 6657310.686761476
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.06554594 2.60289667]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: 0.04762885287842533
# missile.start_distance - missile.defense_missile_to_attack_missile: 4.959584478319803
# Missile.reward_diff: 4.959584478319803
# Reward: 6657310.686761476
# Reward after missile.reward_diff: 6657315.646345954
# ********************************
#
# Distance Reward: 6657315.646345954
# Self.reward after .distance_reward(): 6657310.686761476
# Self.reward after self.reward += distance_reward: 13314626.33310743
# Reward after: 13314626.33310743
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 2.600000000000001
# Attack Missile Coordinates: [0.86081687 3.000964  ]
# Reward: 13314626.33310743
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.06554594 2.60289667]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 2.600000000000001
# Fired Time: 0
# Global Time - Fired Time: 2.600000000000001
# Defense Missile to Attack Missile: 0.04762885287842533
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 4.959584478319803
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 1.9089574110349
# Reward: 13314626.33310743
# Impact Check: (0, False)
# --
# Attack Missile Coordinates: [0.86081687 3.000964  ]
# Attack distance to target: 1.9089574110349
# --
# Defense Missile Coordinates: [1.06554594 2.60289667]
# Defense Missile to Attack Missile: 0.04762885287842533
# Reward Difference: 4.959584478319803
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
#
#
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
# Step 27
# BEFORE STEP: Environment recieved to make step
# global_time: 2.600000000000001
# Attack Missile Coordinates: [0.86081687 3.000964  ]
# Reward: 13314626.33310743
# -------------------------------------------------------------------
# STEP
#
# ++++++++++++++++++++++++++++++++++++++++
# Attack Missile PRINTING: <__main__.Missile object at 0x00000197AFF8FBD0>
# Attack Missile Coordinates: [0.86081687 3.000964  ]
# Attack Missile Theta: 5.261805722100757
# Attack Missile Speed: 1
# Attack Missile Fired Time: 0
# Attack Missile to Target: 1.9089574110349
# --
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Global Time: 2.600000000000001
# Distance to target: 1.9089574110349
# New coord baby: 0.9130358638574281 2.915681078908649
# Missile x: 0.9130358638574281
# Missile y: 2.915681078908649
# Missile coords old: [0.86081687 3.000964  ]
# ----------------------------------------
# Original Attack Stationary Coordinates: [-0.44465787  5.1330371 ]
# Chaning Coords [0.91303586 2.91568108]
# Global Time: 2.600000000000001
# Missile coords new: [0.91303586 2.91568108]
# Missile coords x 0.9130358638574281
# Missile coords y 2.915681078908649
# Distance to target: 1.9089574110349
# ++++++++++++++++++++++++++++++++++++++++
#
# New coord baby: 1.0363087967036024 2.698527156032725
# Missile x: 1.0363087967036024
# Missile y: 2.698527156032725
# Missile coords new: [1.0363088  2.69852716]
#
# ............................................
# DEBUGGING REWARD
# Global Time: 2.600000000000001
# Reward before: 13314626.33310743
# --------------
#
#
# ********************************
# DEBUGGING DISTANE REWARD AS PART OF REWARD
# Missiles:  [<__main__.Missile object at 0x00000197AFCE55D0>]
# Missile Coordinates: [1.0363088  2.69852716]
# Missile.start_distance: 5.007213331198228
# Missile.defense_missile_to_attack_missile: -0.15029609095390542
# missile.start_distance - missile.defense_missile_to_attack_missile: 5.157509422152134
# Missile.reward_diff: 5.157509422152134
# Reward: 13314626.33310743
# Reward after missile.reward_diff: 13314631.490616852
# ********************************
#
# Distance Reward: 13314631.490616852
# Self.reward after .distance_reward(): 13314626.33310743
# Self.reward after self.reward += distance_reward: 26629257.823724285
# Reward after: 26629357.823724285
# ............................................
#
# Step = Create a missile: False, theta: None, fire_now: False
# -------------------------------------------------------------------
# AFTER STEP: Environment after step
# global_time: 2.700000000000001
# Attack Missile Coordinates: [0.91303586 2.91568108]
# Reward: 26629357.823724285
# -------------------------------------------------------------------
# DEFENSE MISSILES
# Defense Missiles Count: 1
# Defense Missiles: [<__main__.Missile object at 0x00000197AFCE55D0>]
#
# ~~~~~~~~~~~~~~~~~
# Defense Missile 1
# Defense Missile Corrdinates: [1.0363088  2.69852716]
# Defense Missile Theta: 1.867502
# Defense Missile Fired: True
# Defense Missile Fired Time: 0
# Defense Missile Missile Clock: 0
# Global Time: 2.700000000000001
# Fired Time: 0
# Global Time - Fired Time: 2.700000000000001
# Defense Missile to Attack Missile: -0.15029609095390542
# Defense Missile Start Distance: 5.007213331198228
# Reward Difference: 5.157509422152134
# ~~~~~~~~~~~~~~~~~
#
# -------------------------------------------------------------------
# IMPACT CHECK & SUMMARY
# Attack Coordinates: [-0.44465787  5.1330371 ]
# Target Coordinates: [2.06653111 1.03181761]
# Defense Coordinates: [1.79647448 0.21213456]
# Attack Missile to Target: 1.8089574110348998
# Reward: 26629357.823724285
# Impact Check: (100, True)
# --
# Attack Missile Coordinates: [0.91303586 2.91568108]
# Attack distance to target: 1.8089574110348998
# --
# Defense Missile Coordinates: [1.0363088  2.69852716]
# Defense Missile to Attack Missile: -0.15029609095390542
# Reward Difference: 5.157509422152134
# --
# --/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/--/-
